# %%
# %matplotlib inline

import math
import subprocess
import numpy as np
import pandas as pd
import scipy.stats as stats
import matplotlib.pyplot as plt

from collections import defaultdict
from scipy.stats.stats import pearsonr

# %%
def call_apriori(fileinput, fileoutput, delimiter=',', target_type='s', 
                 min_nbr_items=1, min_sup=2, min_conf=2):
    # apriori
    # -t# {m: maximal, c: closed, s: frequent, r: association rules}
    # -m# minimum number of items per item set/association rule
    # -s# minimum support of an item set, positive: percentage, negative: absolute
    # -c# minimum confidence rule percentage
    # -b# line delimiter (,)
    # The default additional information output format for rules is " (%X, %C)"
    # %X relative body set support as a percentage
    # %C rule confidence as a percentage
    # %L lift

    if target_type == 'r':
        call_cmd = ['./apriori', '-b%s' % delimiter, '-t%s' % target_type, '-m%s' % min_nbr_items, 
                    '-s%s' % min_sup, '-c%s' % min_conf, '-v (%X, %C, %L)', 
                    fileinput, fileoutput]
    else:
        call_cmd = ['./apriori', '-b%s' % delimiter, '-t%s' % target_type, 
                           '-m%s' % min_nbr_items, '-s%s' % min_sup, fileinput, fileoutput]

    ret = subprocess.call(call_cmd,  stdout=open('apriori_stdout.txt', 'w'), 
                          stderr=open('apriori_stderr.txt', 'w'))
    return ret

# %%
# def read_rules(filename):
#     data = open(filename, 'r')
#     rules = list()
#     for row in data:
#         fileds = row.rstrip('\n').replace('\r','').split(' <- ')
#         cons = fileds[0]
#         other = fileds[1].split(' (')
#         ant = other[0].split(' ')
#         other2 = other[1].split(', ')
#         sup = float(other2[0])
#         conf = float(other2[1])
#         lift = float(other2[2].replace(')', ''))
#         rule = {
#             'ant': ant,
#             'cons': cons,
#             'sup': sup,
#             'conf': conf,
#             'lift': lift
#         }
#         rules.append(rule)
#     data.close()
#     return rules

# %%
def read_rules(filename):
    data = open(filename, 'r')
    rules = list()
    alltxt = data.read()
    alltxt = alltxt.replace('\n','').replace('\r','')
    alltxt = alltxt .replace(')',')*')
    alltxt = alltxt[:-1]
    
    
    for row in alltxt.split('*'):
        print (row)
        fileds = row.rstrip('\n').replace('\r','').split(' <- ')
        cons = fileds[0]
        other = fileds[1].split(' (')
        ant = other[0].split(' ')
        other2 = other[1].split(', ')
        sup = float(other2[0])
        conf = float(other2[1])
        lift = float(other2[2].replace(')', ''))
        rule = {
            'ant': ant,
            'cons': cons,
            'sup': sup,
            'conf': conf,
            'lift': lift
        }
        rules.append(rule)
    data.close()
    return rules

# %%
df = pd.read_csv("diabetes_preprocessed.csv")

# %%
df.head()
# Out:
#    DiabetesPedigreeFunction  Age  GlucoseFill  BloodPressureFill  BMIFill  \
# 0                     0.627   50        148.0               72.0     33.6
# 1                     0.351   31         85.0               66.0     26.6
# 2                     0.672   32        183.0               64.0     23.3
# 3                     0.167   21         89.0               66.0     28.1
# 4                     0.201   30        116.0               74.0     25.6
#
#    Pregnancies  Outcome
# 0            6        1
# 1            1        0
# 2            8        1
# 3            1        0
# 4            5        0

# %%
df.head()
# Out:
#    DiabetesPedigreeFunction  Age  GlucoseFill  BloodPressureFill  BMIFill  \
# 0                     0.627   50        148.0               72.0     33.6
# 1                     0.351   31         85.0               66.0     26.6
# 2                     0.672   32        183.0               64.0     23.3
# 3                     0.167   21         89.0               66.0     28.1
# 4                     0.201   30        116.0               74.0     25.6
#
#    Pregnancies  Outcome
# 0            6        1
# 1            1        0
# 2            8        1
# 3            1        0
# 4            5        0

# %%
df.describe()
# Out:
#        DiabetesPedigreeFunction         Age  GlucoseFill  BloodPressureFill  \
# count                697.000000  697.000000   697.000000         697.000000
# mean                   0.443534   32.008608   121.176471          72.005739
# std                    0.286457   10.362811    29.999169          11.487248
# min                    0.078000   21.000000    44.000000          24.000000
# 25%                    0.239000   24.000000    99.000000          64.000000
# 50%                    0.362000   28.000000   116.000000          72.000000
# 75%                    0.593000   39.000000   140.000000          78.000000
# max                    2.420000   70.000000   199.000000         114.000000
#
#           BMIFill  Pregnancies     Outcome
# count  697.000000   697.000000  697.000000
# mean    32.449641     3.727403    0.381636
# std      6.723821     3.237755    0.486137
# min     18.200000     0.000000    0.000000
# 25%     27.600000     1.000000    0.000000
# 50%     32.300000     3.000000    0.000000
# 75%     36.500000     6.000000    1.000000
# max     67.100000    17.000000    1.000000

# %%
df['AgeGroup'] = pd.cut(df['Age'], bins=range(20, 90, 10), right=False, labels=range(20,80,10))

# %%
df['GlucoseGroup'] = pd.cut(df['GlucoseFill'], bins=range(40, 210, 10), right=False, labels=range(40, 200, 10))

# %%
df['BloodPressureGroup'] = pd.cut(df['BloodPressureFill'], bins=range(20, 121, 10), right=False, labels=range(20, 120, 10))

# %%
range(20, 80, 10)
# Out:
# range(20, 80, 10)

# %%
df['BMIGroup'] = pd.cut(df['BMIFill'], bins=range(15, 80, 10), right=False, labels=range(15, 75, 10))

# %%
df['DiabetesPedigreeFunctionGroup'] = pd.cut(df['DiabetesPedigreeFunction'], bins=[0.0,0.5,1.0,1.5,2.0,2.5], right=False, labels=[0.0,0.5,1.0,1.5,2.0])

# %%
df['PregnanciesGroup'] = pd.cut(df['Pregnancies'], bins=range(0, 17, 3), right=False, labels=range(2, 17, 3))

# %% [markdown]
# For PregnanciesGroup, we give a max number in the range as it's label, others we give  the min value in the range as the label

# %%
df.head()
# Out:
#    DiabetesPedigreeFunction  Age  GlucoseFill  BloodPressureFill  BMIFill  \
# 0                     0.627   50        148.0               72.0     33.6
# 1                     0.351   31         85.0               66.0     26.6
# 2                     0.672   32        183.0               64.0     23.3
# 3                     0.167   21         89.0               66.0     28.1
# 4                     0.201   30        116.0               74.0     25.6
#
#    Pregnancies  Outcome AgeGroup GlucoseGroup BloodPressureGroup BMIGroup  \
# 0            6        1       50          140                 70       25
# 1            1        0       30           80                 60       25
# 2            8        1       30          180                 60       15
# 3            1        0       20           80                 60       25
# 4            5        0       30          110                 70       25
#
#   DiabetesPedigreeFunctionGroup PregnanciesGroup
# 0                           0.5                8
# 1                           0.0                2
# 2                           0.5                8
# 3                           0.0                2
# 4                           0.0                5

# %%
df.drop(['DiabetesPedigreeFunction','Age', 'GlucoseFill','BloodPressureFill','BMIFill','Pregnancies'], axis=1, inplace=True)
df.head()
# Out:
#    Outcome AgeGroup GlucoseGroup BloodPressureGroup BMIGroup  \
# 0        1       50          140                 70       25
# 1        0       30           80                 60       25
# 2        1       30          180                 60       15
# 3        0       20           80                 60       25
# 4        0       30          110                 70       25
#
#   DiabetesPedigreeFunctionGroup PregnanciesGroup
# 0                           0.5                8
# 1                           0.0                2
# 2                           0.5                8
# 3                           0.0                2
# 4                           0.0                5

# %%
df1 = df
#D = diabetic and N = Non-diabetic
df1['Outcome'] = df['Outcome'].astype(str) + '_D'
df1['AgeGroup'] = df['AgeGroup'].astype(str) + '_A'
df1['GlucoseGroup'] = df['GlucoseGroup'].astype(str) + '_G'
df1['BloodPressureGroup'] = df['BloodPressureGroup'].astype(str) + '_B'
df1['BMIGroup'] = df['BMIGroup'].astype(str) + '_BMI'
df1['DiabetesPedigreeFunctionGroup'] = df['DiabetesPedigreeFunctionGroup'].astype(str) + '_F'
df1['PregnanciesGroup'] = df['PregnanciesGroup'].astype(str) + '_P'

# %%
df1.head()
# Out:
#   Outcome AgeGroup GlucoseGroup BloodPressureGroup BMIGroup  \
# 0     1_D     50_A        140_G               70_B   25_BMI
# 1     0_D     30_A         80_G               60_B   25_BMI
# 2     1_D     30_A        180_G               60_B   15_BMI
# 3     0_D     20_A         80_G               60_B   25_BMI
# 4     0_D     30_A        110_G               70_B   25_BMI
#
#   DiabetesPedigreeFunctionGroup PregnanciesGroup
# 0                         0.5_F            8.0_P
# 1                         0.0_F            2.0_P
# 2                         0.5_F            8.0_P
# 3                         0.0_F            2.0_P
# 4                         0.0_F            5.0_P

# %%
df1.to_csv('PIMA_for_patterns.csv', header=False)

# %%
delimiter=','
target_type='c'
min_nbr_items=3
min_sup=20
#min_conf=2

ret_val = call_apriori('PIMA_for_patterns.csv', 'PIMA_freq_patterns_target_type_c.txt', 
                       delimiter, target_type, min_nbr_items, min_sup)

# %%
delimiter=','
target_type='m'
min_nbr_items=3
min_sup=20
#min_conf=2

ret_val = call_apriori('PIMA_for_patterns.csv', 'PIMA_freq_patterns_target_type_m.txt', 
                       delimiter, target_type, min_nbr_items, min_sup)

# %%
delimiter=','
target_type='s'
min_nbr_items=3
min_sup=10
#min_conf=2

ret_val = call_apriori('PIMA_for_patterns.csv', 'PIMA_freq_patterns.txt', 
                       delimiter, target_type, min_nbr_items, min_sup)

# %%
delimiter=','
target_type='r'
min_nbr_items=3
min_sup=10
min_conf=25

ret_val = call_apriori('PIMA_for_patterns.csv', 'PIMA_rules.txt', delimiter, target_type, 
                       min_nbr_items, min_sup, min_conf)

# %%
rules = read_rules('PIMA_rules.txt')
print(len(rules))
for r in rules:
     print (r['ant'], '-->', r['cons'], ' lift', r['lift'], ' conf', r['conf'])
# Out:
# 15_BMI <- 90_G 0_D (10.9039, 30.2632, 226.811)
# 90_G <- 15_BMI 0_D (12.3386, 26.7442, 219.302)
# 90_G <- 15_BMI 0.0_F (10.4735, 26.0274, 213.425)
# 5.0_P <- 90_G 0_D (10.9039, 27.6316, 104.104)
# 90_G <- 60_B 2.0_P 20_A 0_D (10.7604, 26.6667, 218.667)
# 60_B <- 90_G 0_D (10.9039, 39.4737, 148.72)
# 0.5_F <- 90_G 0_D (10.9039, 25, 82.9762)
# 70_B <- 90_G 0_D (10.9039, 32.8947, 87.8453)
# 2.0_P <- 90_G 0_D (10.9039, 55.2632, 120.37)
# 20_A <- 90_G 0_D (10.9039, 75, 137.929)
# 25_BMI <- 90_G 0_D (10.9039, 47.3684, 86.8837)
# 0.0_F <- 90_G 0_D (10.9039, 75, 113.889)
# 5.0_P <- 15_BMI 0.0_F (10.4735, 27.3973, 103.221)
# 15_BMI <- 60_B 2.0_P 20_A 0_D (10.7604, 28, 209.849)
# 15_BMI <- 60_B 2.0_P 0_D (11.6212, 27.1605, 203.558)
# 15_BMI <- 60_B 20_A 0_D 0.0_F (11.3343, 30.3797, 227.685)
# 15_BMI <- 60_B 20_A 0_D (14.7776, 26.2136, 196.461)
# 15_BMI <- 60_B 20_A 0.0_F (12.1951, 28.2353, 211.613)
# 15_BMI <- 60_B 0_D 0.0_F (14.2037, 29.2929, 219.539)
# 60_B <- 15_BMI 0_D (12.3386, 38.3721, 144.569)
# 15_BMI <- 60_B 0_D (18.7948, 25.1908, 188.796)
# 60_B <- 15_BMI 0.0_F (10.4735, 41.0959, 154.832)
# 70_B <- 15_BMI 0_D (12.3386, 26.7442, 71.4203)
# 70_B <- 15_BMI 0.0_F (10.4735, 26.0274, 69.5061)
# 15_BMI <- 2.0_P 20_A 0_D 0.0_F (21.5208, 26, 194.86)
# 2.0_P <- 15_BMI 0_D (12.3386, 58.1395, 126.635)
# 2.0_P <- 15_BMI 0.0_F (10.4735, 54.7945, 119.349)
# 15_BMI <- 20_A 0_D 0.0_F (30.99, 25, 187.366)
# 20_A <- 15_BMI 0_D (12.3386, 73.2558, 134.721)
# 20_A <- 15_BMI 0.0_F (10.4735, 73.9726, 136.039)
# 0.0_F <- 15_BMI 0_D (12.3386, 79.0698, 120.069)
# 0_D <- 15_BMI 0.0_F (10.4735, 93.1507, 150.64)
# 8.0_P <- 40_A 0.0_F (10.9039, 38.1579, 216.228)
# 40_A <- 8.0_P 0.0_F (11.1908, 37.1795, 244.473)
# 40_A <- 35_BMI 1_D (13.6298, 27.3684, 179.96)
# 35_BMI <- 40_A 0.0_F (10.9039, 28.9474, 104.002)
# 70_B <- 40_A 0.0_F (10.9039, 39.4737, 105.414)
# 40_A <- 1_D 25_BMI 0.0_F (11.3343, 29.1139, 191.438)
# 1_D <- 40_A 0.0_F (10.9039, 55.2632, 144.806)
# 40_A <- 1_D 0.0_F (20.2296, 29.7872, 195.865)
# 25_BMI <- 40_A 0.0_F (10.9039, 57.8947, 106.191)
# 0_D <- 40_A 0.0_F (10.9039, 44.7368, 72.3471)
# 60_B <- 100_G 20_A (10.1865, 40.8451, 153.887)
# 60_B <- 100_G 0_D (11.7647, 30.4878, 114.865)
# 100_G <- 0.5_F 2.0_P 0_D (10.33, 25, 158.409)
# 0.5_F <- 100_G 20_A (10.1865, 36.6197, 121.543)
# 0.5_F <- 100_G 0_D (11.7647, 30.4878, 101.19)
# 70_B <- 100_G 20_A (10.1865, 26.7606, 71.464)
# 70_B <- 100_G 0_D (11.7647, 32.9268, 87.931)
# 100_G <- 2.0_P 20_A 25_BMI 0_D 0.0_F (10.1865, 25.3521, 160.64)
# 2.0_P <- 100_G 20_A (10.1865, 77.4648, 168.728)
# 100_G <- 2.0_P 25_BMI 0_D 0.0_F (11.4778, 25, 158.409)
# 2.0_P <- 100_G 0_D (11.7647, 68.2927, 148.75)
# 25_BMI <- 100_G 20_A (10.1865, 56.338, 103.336)
# 0_D <- 100_G 20_A (10.1865, 87.3239, 141.218)
# 20_A <- 100_G 0_D (11.7647, 75.6098, 139.05)
# 0.0_F <- 100_G 20_A (10.1865, 63.3803, 96.2441)
# 25_BMI <- 100_G 0_D (11.7647, 51.2195, 93.9474)
# 0.0_F <- 100_G 0_D (11.7647, 69.5122, 105.556)
# 8.0_P <- 30_A 70_B (10.33, 30.5556, 173.148)
# 8.0_P <- 30_A 1_D (10.7604, 28, 158.667)
# 8.0_P <- 30_A 25_BMI (13.6298, 30.5263, 172.982)
# 8.0_P <- 30_A 0_D (11.0473, 27.2727, 154.545)
# 30_A <- 8.0_P 0.0_F (11.1908, 28.2051, 129.335)
# 8.0_P <- 0.5_F 70_B (11.1908, 28.2051, 159.829)
# 70_B <- 8.0_P 0.0_F (11.1908, 38.4615, 102.711)
# 8.0_P <- 1_D 25_BMI 0.0_F (11.3343, 27.8481, 157.806)
# 8.0_P <- 1_D 25_BMI (20.5165, 25.1748, 142.657)
# 1_D <- 8.0_P 0.0_F (11.1908, 47.4359, 124.296)
# 8.0_P <- 1_D 0.0_F (20.2296, 26.2411, 148.7)
# 25_BMI <- 8.0_P 0.0_F (11.1908, 57.6923, 105.82)
# 0_D <- 8.0_P 0.0_F (11.1908, 52.5641, 85.0051)
# 5.0_P <- 80_B 0.0_F (10.4735, 32.8767, 123.865)
# 80_B <- 35_BMI 1_D (13.6298, 25.2632, 139.749)
# 80_B <- 35_BMI 0_D 0.0_F (10.33, 26.3889, 145.977)
# 80_B <- 35_BMI 0_D (14.2037, 26.2626, 145.278)
# 35_BMI <- 80_B 0.0_F (10.4735, 38.3562, 137.805)
# 1_D <- 80_B 0.0_F (10.4735, 38.3562, 100.505)
# 2.0_P <- 80_B 0.0_F (10.4735, 36.9863, 80.5608)
# 20_A <- 80_B 0.0_F (10.4735, 46.5753, 85.6544)
# 25_BMI <- 80_B 0.0_F (10.4735, 47.9452, 87.9416)
# 0_D <- 80_B 0.0_F (10.4735, 61.6438, 99.6885)
# 5.0_P <- 30_A 70_B (10.33, 38.8889, 146.517)
# 30_A <- 5.0_P 70_B (11.0473, 36.3636, 166.746)
# 5.0_P <- 30_A 1_D (10.7604, 32, 120.562)
# 30_A <- 5.0_P 1_D (10.1865, 33.8028, 155.004)
# 30_A <- 5.0_P 25_BMI 0_D (10.043, 34.2857, 157.218)
# 30_A <- 5.0_P 25_BMI 0.0_F (11.9082, 32.5301, 149.168)
# 5.0_P <- 30_A 25_BMI (13.6298, 40, 150.703)
# 30_A <- 5.0_P 25_BMI (16.2123, 33.6283, 154.204)
# 30_A <- 5.0_P 0_D 0.0_F (13.6298, 30.5263, 139.979)
# 5.0_P <- 30_A 0_D (11.0473, 48.0519, 181.039)
# 30_A <- 5.0_P 0_D (16.3558, 32.4561, 148.828)
# 5.0_P <- 30_A 0.0_F (13.6298, 47.3684, 178.464)
# 30_A <- 5.0_P 0.0_F (19.7991, 32.6087, 149.528)
# 35_BMI <- 30_A 70_B (10.33, 27.7778, 99.7995)
# 30_A <- 35_BMI 70_B (10.6169, 27.027, 123.933)
# 35_BMI <- 30_A 1_D (10.7604, 28, 100.598)
# 0.5_F <- 30_A 70_B (10.33, 30.5556, 101.415)
# 30_A <- 0.5_F 70_B (11.1908, 28.2051, 129.335)
# 0.5_F <- 30_A 1_D (10.7604, 37.3333, 123.911)
# 30_A <- 0.5_F 1_D (13.9168, 28.866, 132.366)
# 0.5_F <- 30_A 25_BMI (13.6298, 30.5263, 101.318)
# 30_A <- 0.5_F 25_BMI (16.3558, 25.4386, 116.649)
# 0.5_F <- 30_A 0_D (11.0473, 25.974, 86.209)
# 1_D <- 30_A 70_B (10.33, 51.3889, 134.654)
# 70_B <- 30_A 1_D (10.7604, 49.3333, 131.745)
# 30_A <- 70_B 1_D (15.495, 34.2593, 157.097)
# 30_A <- 70_B 25_BMI 0_D (12.4821, 26.4368, 121.227)
# 30_A <- 70_B 25_BMI 0.0_F (13.9168, 29.8969, 137.093)
# 25_BMI <- 30_A 70_B (10.33, 65.2778, 119.733)
# 70_B <- 30_A 25_BMI (13.6298, 49.4737, 132.119)
# 30_A <- 70_B 25_BMI (21.2339, 31.7568, 145.621)
# 0_D <- 30_A 70_B (10.33, 48.6111, 78.6124)
# 70_B <- 30_A 0_D (11.0473, 45.4545, 121.386)
# 0.0_F <- 30_A 70_B (10.33, 63.8889, 97.0165)
# 70_B <- 30_A 0.0_F (13.6298, 48.4211, 129.308)
# 30_A <- 70_B 0.0_F (24.5337, 26.9006, 123.353)
# 2.0_P <- 30_A 1_D (10.7604, 25.3333, 55.1792)
# 30_A <- 1_D 25_BMI 0.0_F (11.3343, 30.3797, 139.307)
# 25_BMI <- 30_A 1_D (10.7604, 61.3333, 112.498)
# 1_D <- 30_A 25_BMI (13.6298, 48.4211, 126.878)
# 30_A <- 1_D 25_BMI (20.5165, 32.1678, 147.506)
# 0.0_F <- 30_A 1_D (10.7604, 50.6667, 76.9383)
# 1_D <- 30_A 0.0_F (13.6298, 40, 104.812)
# 30_A <- 1_D 0.0_F (20.2296, 26.9504, 123.582)
# 0_D <- 30_A 25_BMI (13.6298, 51.5789, 83.4119)
# 25_BMI <- 30_A 0_D (11.0473, 63.6364, 116.722)
# 0.0_F <- 30_A 25_BMI (13.6298, 64.2105, 97.5049)
# 25_BMI <- 30_A 0.0_F (13.6298, 64.2105, 117.776)
# 0.0_F <- 30_A 0_D (11.0473, 74.026, 112.41)
# 0_D <- 30_A 0.0_F (13.6298, 60, 97.0302)
# 5.0_P <- 60_B 20_A 0_D 0.0_F (11.3343, 27.8481, 104.92)
# 60_B <- 5.0_P 20_A 0.0_F (10.4735, 32.8767, 123.865)
# 5.0_P <- 60_B 20_A 0.0_F (12.1951, 28.2353, 106.378)
# 60_B <- 5.0_P 20_A (13.7733, 31.25, 117.736)
# 60_B <- 5.0_P 25_BMI 0_D (10.043, 30, 113.027)
# 5.0_P <- 60_B 25_BMI 0_D (10.1865, 29.5775, 111.435)
# 60_B <- 5.0_P 25_BMI 0.0_F (11.9082, 27.7108, 104.402)
# 5.0_P <- 60_B 25_BMI 0.0_F (10.6169, 31.0811, 117.1)
# 60_B <- 5.0_P 25_BMI (16.2123, 26.5487, 100.024)
# 5.0_P <- 60_B 25_BMI (15.0646, 28.5714, 107.645)
# 60_B <- 5.0_P 0_D 0.0_F (13.6298, 27.3684, 103.112)
# 5.0_P <- 60_B 0_D 0.0_F (14.2037, 26.2626, 98.9462)
# 60_B <- 5.0_P 0_D (16.3558, 27.193, 102.451)
# 5.0_P <- 60_B 0.0_F (18.3644, 26.5625, 100.076)
# 35_BMI <- 5.0_P 1_D (10.1865, 30.9859, 111.326)
# 5.0_P <- 35_BMI 0_D 0.0_F (10.33, 25, 94.1892)
# 5.0_P <- 35_BMI 0.0_F (16.6428, 25.8621, 97.4371)
# 0.5_F <- 5.0_P 1_D (10.1865, 28.169, 93.4943)
# 1_D <- 5.0_P 70_B (11.0473, 44.1558, 115.702)
# 70_B <- 5.0_P 1_D (10.1865, 47.8873, 127.883)
# 5.0_P <- 70_B 1_D (15.495, 31.4815, 118.609)
# 70_B <- 5.0_P 20_A 0.0_F (10.4735, 32.8767, 87.7972)
# 5.0_P <- 70_B 20_A 0.0_F (12.0516, 28.5714, 107.645)
# 20_A <- 5.0_P 70_B (11.0473, 41.5584, 76.4281)
# 70_B <- 5.0_P 20_A (13.7733, 33.3333, 89.0166)
# 5.0_P <- 70_B 20_A (17.0732, 26.8908, 101.313)
# 70_B <- 5.0_P 25_BMI 0_D (10.043, 34.2857, 91.5599)
# 5.0_P <- 70_B 25_BMI 0_D (12.4821, 27.5862, 103.933)
# 70_B <- 5.0_P 25_BMI 0.0_F (11.9082, 39.759, 106.176)
# 5.0_P <- 70_B 25_BMI 0.0_F (13.9168, 34.0206, 128.175)
# 25_BMI <- 5.0_P 70_B (11.0473, 61.039, 111.958)
# 70_B <- 5.0_P 25_BMI (16.2123, 41.5929, 111.074)
# 5.0_P <- 70_B 25_BMI (21.2339, 31.7568, 119.646)
# 70_B <- 5.0_P 0_D 0.0_F (13.6298, 37.8947, 101.198)
# 5.0_P <- 70_B 0_D 0.0_F (16.2123, 31.8584, 120.029)
# 0_D <- 5.0_P 70_B (11.0473, 55.8442, 90.3095)
# 70_B <- 5.0_P 0_D (16.3558, 37.7193, 100.729)
# 5.0_P <- 70_B 0_D (21.9512, 28.1046, 105.886)
# 0.0_F <- 5.0_P 70_B (11.0473, 74.026, 112.41)
# 70_B <- 5.0_P 0.0_F (19.7991, 41.3043, 110.303)
# 5.0_P <- 70_B 0.0_F (24.5337, 33.3333, 125.586)
# 20_A <- 5.0_P 1_D (10.1865, 42.2535, 77.7063)
# 1_D <- 5.0_P 20_A (13.7733, 31.25, 81.8844)
# 5.0_P <- 1_D 20_A (11.9082, 36.1446, 136.177)
# 1_D <- 5.0_P 25_BMI 0.0_F (11.9082, 31.3253, 82.0817)
# 5.0_P <- 1_D 25_BMI 0.0_F (11.3343, 32.9114, 123.996)
# 25_BMI <- 5.0_P 1_D (10.1865, 60.5634, 111.086)
# 1_D <- 5.0_P 25_BMI (16.2123, 38.0531, 99.7106)
# 5.0_P <- 1_D 25_BMI (20.5165, 30.0699, 113.29)
# 0.0_F <- 5.0_P 1_D (10.1865, 60.5634, 91.9666)
# 1_D <- 5.0_P 0.0_F (19.7991, 31.1594, 81.6471)
# 5.0_P <- 1_D 0.0_F (20.2296, 30.4965, 114.897)
# 5.0_P <- 20_A 25_BMI 0_D 0.0_F (15.7819, 30.9091, 116.452)
# 20_A <- 5.0_P 25_BMI 0_D (10.043, 58.5714, 107.716)
# 5.0_P <- 20_A 25_BMI 0_D (22.3816, 26.2821, 99.0194)
# 25_BMI <- 5.0_P 20_A 0.0_F (10.4735, 61.6438, 113.068)
# 20_A <- 5.0_P 25_BMI 0.0_F (11.9082, 54.2169, 99.7075)
# 5.0_P <- 20_A 25_BMI 0.0_F (18.9383, 34.0909, 128.44)
# 25_BMI <- 5.0_P 20_A (13.7733, 62.5, 114.638)
# 20_A <- 5.0_P 25_BMI (16.2123, 53.0973, 97.6487)
# 5.0_P <- 20_A 25_BMI (28.1205, 30.6122, 115.334)
# 0_D <- 5.0_P 20_A 0.0_F (10.4735, 76.7123, 124.057)
# 20_A <- 5.0_P 0_D 0.0_F (13.6298, 58.9474, 108.407)
# 5.0_P <- 20_A 0_D 0.0_F (30.99, 25.9259, 97.6777)
# 0_D <- 5.0_P 20_A (13.7733, 68.75, 111.18)
# 20_A <- 5.0_P 0_D (16.3558, 57.8947, 106.471)
# 0.0_F <- 5.0_P 20_A (13.7733, 76.0417, 115.471)
# 20_A <- 5.0_P 0.0_F (19.7991, 52.8986, 97.2831)
# 5.0_P <- 20_A 0.0_F (37.0158, 28.2946, 106.602)
# 0.0_F <- 5.0_P 25_BMI 0_D (10.043, 81.4286, 123.651)
# 0_D <- 5.0_P 25_BMI 0.0_F (11.9082, 68.6747, 111.059)
# 25_BMI <- 5.0_P 0_D 0.0_F (13.6298, 60, 110.053)
# 5.0_P <- 25_BMI 0_D 0.0_F (24.6772, 33.1395, 124.855)
# 0_D <- 5.0_P 25_BMI (16.2123, 61.9469, 100.179)
# 25_BMI <- 5.0_P 0_D (16.3558, 61.4035, 112.627)
# 5.0_P <- 25_BMI 0_D (34.0029, 29.5359, 111.278)
# 0.0_F <- 5.0_P 25_BMI (16.2123, 73.4513, 111.537)
# 25_BMI <- 5.0_P 0.0_F (19.7991, 60.1449, 110.318)
# 5.0_P <- 25_BMI 0.0_F (36.0115, 33.0677, 124.585)
# 0.0_F <- 5.0_P 0_D (16.3558, 83.3333, 126.543)
# 0_D <- 5.0_P 0.0_F (19.7991, 68.8406, 111.327)
# 5.0_P <- 0_D 0.0_F (45.6241, 29.8742, 112.553)
# 35_BMI <- 60_B 2.0_P 20_A 0_D (10.7604, 29.3333, 105.388)
# 35_BMI <- 60_B 2.0_P 20_A (12.9125, 33.3333, 119.759)
# 60_B <- 35_BMI 2.0_P 20_A (11.3343, 37.9747, 143.072)
# 35_BMI <- 60_B 2.0_P 0_D (11.6212, 27.1605, 97.5818)
# 35_BMI <- 60_B 2.0_P (14.7776, 30.0971, 108.132)
# 60_B <- 35_BMI 2.0_P (13.7733, 32.2917, 121.661)
# 35_BMI <- 60_B 20_A 0_D (14.7776, 25.2427, 90.6916)
# 60_B <- 35_BMI 20_A 0_D (10.33, 36.1111, 136.051)
# 35_BMI <- 60_B 20_A (17.934, 28, 100.598)
# 60_B <- 35_BMI 20_A (15.0646, 33.3333, 125.586)
# 60_B <- 35_BMI 0_D (14.2037, 26.2626, 98.9462)
# 0.5_F <- 60_B 2.0_P 20_A 0_D (10.7604, 28, 92.9333)
# 0.5_F <- 60_B 2.0_P 20_A (12.9125, 33.3333, 110.635)
# 60_B <- 0.5_F 2.0_P 20_A (12.4821, 34.4828, 129.916)
# 0.5_F <- 60_B 2.0_P 0_D (11.6212, 28.3951, 94.2446)
# 60_B <- 0.5_F 2.0_P 0_D (10.33, 31.9444, 120.353)
# 0.5_F <- 60_B 2.0_P (14.7776, 33.0097, 109.561)
# 60_B <- 0.5_F 2.0_P (15.0646, 32.381, 121.997)
# 60_B <- 0.5_F 20_A 0_D (11.4778, 30, 113.027)
# 0.5_F <- 60_B 20_A (17.934, 29.6, 98.2438)
# 60_B <- 0.5_F 20_A (16.0689, 33.0357, 124.464)
# 0.5_F <- 60_B 25_BMI 0_D (10.1865, 25.3521, 84.1449)
# 0.5_F <- 60_B 25_BMI (15.0646, 27.619, 91.6689)
# 60_B <- 0.5_F 25_BMI (16.3558, 25.4386, 95.8416)
# 60_B <- 0.5_F 0_D (16.2123, 28.3186, 106.692)
# 60_B <- 1_D 2.0_P (12.0516, 26.1905, 98.6744)
# 60_B <- 1_D 20_A (11.9082, 26.506, 99.8632)
# 1_D <- 60_B 25_BMI 0.0_F (10.6169, 28.3784, 74.3599)
# 60_B <- 1_D 25_BMI 0.0_F (11.3343, 26.5823, 100.151)
# 1_D <- 60_B 25_BMI (15.0646, 32.381, 84.8478)
# 60_B <- 2.0_P 20_A 25_BMI 0_D 0.0_F (10.1865, 32.3944, 122.048)
# 25_BMI <- 60_B 2.0_P 20_A 0_D (10.7604, 42.6667, 78.2596)
# 60_B <- 2.0_P 20_A 25_BMI 0_D (15.6385, 29.3578, 110.607)
# 60_B <- 2.0_P 20_A 25_BMI 0.0_F (11.1908, 30.7692, 115.925)
# 25_BMI <- 60_B 2.0_P 20_A (12.9125, 43.3333, 79.4825)
# 60_B <- 2.0_P 20_A 25_BMI (18.0775, 30.9524, 116.615)
# 0.0_F <- 60_B 2.0_P 20_A 0_D (10.7604, 72, 109.333)
# 2.0_P <- 60_B 20_A 0_D 0.0_F (11.3343, 68.3544, 148.884)
# 60_B <- 2.0_P 20_A 0_D 0.0_F (21.5208, 36, 135.632)
# 0_D <- 60_B 2.0_P 20_A (12.9125, 83.3333, 134.764)
# 20_A <- 60_B 2.0_P 0_D (11.6212, 92.5926, 170.282)
# 2.0_P <- 60_B 20_A 0_D (14.7776, 72.8155, 158.601)
# 60_B <- 2.0_P 20_A 0_D (30.99, 34.7222, 130.818)
# 0.0_F <- 60_B 2.0_P 20_A (12.9125, 63.3333, 96.1728)
# 2.0_P <- 60_B 20_A 0.0_F (12.1951, 67.0588, 146.062)
# 60_B <- 2.0_P 20_A 0.0_F (24.5337, 33.3333, 125.586)
# 20_A <- 60_B 2.0_P (14.7776, 87.3786, 160.694)
# 2.0_P <- 60_B 20_A (17.934, 72, 156.825)
# 60_B <- 2.0_P 20_A (37.8766, 34.0909, 128.44)
# 60_B <- 2.0_P 25_BMI 0_D 0.0_F (11.4778, 33.75, 127.155)
# 25_BMI <- 60_B 2.0_P 0_D (11.6212, 45.679, 83.7849)
# 2.0_P <- 60_B 25_BMI 0_D (10.1865, 52.1127, 113.508)
# 60_B <- 2.0_P 25_BMI 0_D (17.3601, 30.5785, 115.207)
# 2.0_P <- 60_B 25_BMI 0.0_F (10.6169, 44.5946, 97.1326)
# 60_B <- 2.0_P 25_BMI 0.0_F (14.0603, 33.6735, 126.867)
# 25_BMI <- 60_B 2.0_P (14.7776, 48.5437, 89.0393)
# 2.0_P <- 60_B 25_BMI (15.0646, 47.619, 103.72)
# 60_B <- 2.0_P 25_BMI (22.6686, 31.6456, 119.227)
# 0.0_F <- 60_B 2.0_P 0_D (11.6212, 71.6049, 108.733)
# 2.0_P <- 60_B 0_D 0.0_F (14.2037, 58.5859, 127.607)
# 60_B <- 2.0_P 0_D 0.0_F (23.5294, 35.3659, 133.243)
# 0_D <- 60_B 2.0_P (14.7776, 78.6408, 127.175)
# 2.0_P <- 60_B 0_D (18.7948, 61.8321, 134.678)
# 60_B <- 2.0_P 0_D (33.8594, 34.322, 129.311)
# 0.0_F <- 60_B 2.0_P (14.7776, 64.0777, 97.3031)
# 2.0_P <- 60_B 0.0_F (18.3644, 51.5625, 112.31)
# 60_B <- 2.0_P 0.0_F (29.4118, 32.1951, 121.297)
# 25_BMI <- 60_B 20_A 0_D 0.0_F (11.3343, 49.3671, 90.5496)
# 60_B <- 20_A 25_BMI 0_D 0.0_F (15.7819, 35.4545, 133.577)
# 25_BMI <- 60_B 20_A 0_D (14.7776, 48.5437, 89.0393)
# 20_A <- 60_B 25_BMI 0_D (10.1865, 70.4225, 129.511)
# 60_B <- 20_A 25_BMI 0_D (22.3816, 32.0513, 120.755)
# 25_BMI <- 60_B 20_A 0.0_F (12.1951, 50.5882, 92.7895)
# 20_A <- 60_B 25_BMI 0.0_F (10.6169, 58.1081, 106.864)
# 60_B <- 20_A 25_BMI 0.0_F (18.9383, 32.5758, 122.731)
# 25_BMI <- 60_B 20_A (17.934, 49.6, 90.9768)
# 20_A <- 60_B 25_BMI (15.0646, 59.0476, 108.592)
# 60_B <- 20_A 25_BMI (28.1205, 31.6327, 119.178)
# 0.0_F <- 60_B 20_A 0_D (14.7776, 76.699, 116.469)
# 0_D <- 60_B 20_A 0.0_F (12.1951, 92.9412, 150.302)
# 20_A <- 60_B 0_D 0.0_F (14.2037, 79.798, 146.752)
# 60_B <- 20_A 0_D 0.0_F (30.99, 36.5741, 137.795)
# 0_D <- 60_B 20_A (17.934, 82.4, 133.255)
# 20_A <- 60_B 0_D (18.7948, 78.626, 144.597)
# 60_B <- 20_A 0_D (42.4677, 34.7973, 131.101)
# 0.0_F <- 60_B 20_A (17.934, 68, 103.259)
# 20_A <- 60_B 0.0_F (18.3644, 66.4062, 122.124)
# 60_B <- 20_A 0.0_F (37.0158, 32.9457, 124.125)
# 0.0_F <- 60_B 25_BMI 0_D (10.1865, 74.6479, 113.354)
# 0_D <- 60_B 25_BMI 0.0_F (10.6169, 71.6216, 115.824)
# 25_BMI <- 60_B 0_D 0.0_F (14.2037, 53.5354, 98.1951)
# 60_B <- 25_BMI 0_D 0.0_F (24.6772, 30.814, 116.094)
# 0_D <- 60_B 25_BMI (15.0646, 67.619, 109.351)
# 25_BMI <- 60_B 0_D (18.7948, 54.1985, 99.4114)
# 60_B <- 25_BMI 0_D (34.0029, 29.9578, 112.868)
# 0.0_F <- 60_B 25_BMI (15.0646, 70.4762, 107.019)
# 25_BMI <- 60_B 0.0_F (18.3644, 57.8125, 106.04)
# 60_B <- 25_BMI 0.0_F (36.0115, 29.4821, 111.076)
# 0.0_F <- 60_B 0_D (18.7948, 75.5725, 114.758)
# 0_D <- 60_B 0.0_F (18.3644, 77.3438, 125.078)
# 60_B <- 0_D 0.0_F (45.6241, 31.1321, 117.292)
# 0.5_F <- 35_BMI 70_B (10.6169, 28.3784, 94.1892)
# 35_BMI <- 0.5_F 70_B (11.1908, 26.9231, 96.7288)
# 0.5_F <- 35_BMI 1_D (13.6298, 42.1053, 139.749)
# 35_BMI <- 0.5_F 1_D (13.9168, 41.2371, 148.156)
# 0.5_F <- 35_BMI 2.0_P 20_A (11.3343, 35.443, 117.637)
# 35_BMI <- 0.5_F 2.0_P 20_A (12.4821, 32.1839, 115.63)
# 35_BMI <- 0.5_F 2.0_P 0_D (10.33, 25, 89.8196)
# 0.5_F <- 35_BMI 2.0_P (13.7733, 33.3333, 110.635)
# 35_BMI <- 0.5_F 2.0_P (15.0646, 30.4762, 109.494)
# 0.5_F <- 35_BMI 20_A 0_D (10.33, 30.5556, 101.415)
# 35_BMI <- 0.5_F 20_A 0_D (11.4778, 27.5, 98.8015)
# 0.5_F <- 35_BMI 20_A (15.0646, 35.2381, 116.957)
# 35_BMI <- 0.5_F 20_A (16.0689, 33.0357, 118.69)
# 0.5_F <- 35_BMI 0_D (14.2037, 27.2727, 90.5195)
# 1_D <- 35_BMI 70_B (10.6169, 50, 131.015)
# 70_B <- 35_BMI 1_D (13.6298, 38.9474, 104.009)
# 35_BMI <- 70_B 1_D (15.495, 34.2593, 123.086)
# 70_B <- 35_BMI 2.0_P 20_A (11.3343, 29.1139, 77.7487)
# 35_BMI <- 70_B 2.0_P 20_A (11.4778, 28.75, 103.293)
# 35_BMI <- 70_B 2.0_P 0_D (10.33, 26.3889, 94.8096)
# 2.0_P <- 35_BMI 70_B (10.6169, 44.5946, 97.1326)
# 70_B <- 35_BMI 2.0_P (13.7733, 34.375, 91.7984)
# 35_BMI <- 70_B 2.0_P (14.4907, 32.6733, 117.388)
# 70_B <- 35_BMI 20_A 0_D (10.33, 30.5556, 81.5986)
# 35_BMI <- 70_B 20_A 0.0_F (12.0516, 25, 89.8196)
# 20_A <- 35_BMI 70_B (10.6169, 41.8919, 77.0413)
# 70_B <- 35_BMI 20_A (15.0646, 29.5238, 78.8433)
# 35_BMI <- 70_B 20_A (17.0732, 26.0504, 93.5935)
# 70_B <- 35_BMI 0_D 0.0_F (10.33, 43.0556, 114.98)
# 35_BMI <- 70_B 0_D 0.0_F (16.2123, 27.4336, 98.5631)
# 0_D <- 35_BMI 70_B (10.6169, 50, 80.8585)
# 70_B <- 35_BMI 0_D (14.2037, 37.3737, 99.8065)
# 0.0_F <- 35_BMI 70_B (10.6169, 63.5135, 96.4464)
# 70_B <- 35_BMI 0.0_F (16.6428, 40.5172, 108.201)
# 35_BMI <- 70_B 0.0_F (24.5337, 27.4854, 98.749)
# 1_D <- 35_BMI 2.0_P 20_A (11.3343, 30.3797, 79.6041)
# 2.0_P <- 35_BMI 1_D (13.6298, 37.8947, 82.5395)
# 1_D <- 35_BMI 2.0_P (13.7733, 37.5, 98.2613)
# 35_BMI <- 1_D 2.0_P (12.0516, 42.8571, 153.976)
# 20_A <- 35_BMI 1_D (13.6298, 34.7368, 63.8828)
# 1_D <- 35_BMI 20_A (15.0646, 31.4286, 82.3523)
# 35_BMI <- 1_D 20_A (11.9082, 39.759, 142.846)
# 0.0_F <- 35_BMI 1_D (13.6298, 46.3158, 70.3314)
# 1_D <- 35_BMI 0.0_F (16.6428, 37.931, 99.3907)
# 35_BMI <- 1_D 0.0_F (20.2296, 31.2057, 112.115)
# 35_BMI <- 2.0_P 20_A 0_D 0.0_F (21.5208, 25.3333, 91.0172)
# 0_D <- 35_BMI 2.0_P 20_A (11.3343, 69.6203, 112.588)
# 2.0_P <- 35_BMI 20_A 0_D (10.33, 76.3889, 166.385)
# 35_BMI <- 2.0_P 20_A 0_D (30.99, 25.463, 91.4829)
# 0.0_F <- 35_BMI 2.0_P 20_A (11.3343, 60.7595, 92.2644)
# 35_BMI <- 2.0_P 20_A 0.0_F (24.5337, 28.0702, 100.85)
# 20_A <- 35_BMI 2.0_P (13.7733, 82.2917, 151.339)
# 2.0_P <- 35_BMI 20_A (15.0646, 75.2381, 163.878)
# 35_BMI <- 2.0_P 20_A (37.8766, 29.9242, 107.511)
# 2.0_P <- 35_BMI 0_D 0.0_F (10.33, 58.3333, 127.057)
# 35_BMI <- 2.0_P 0_D 0.0_F (23.5294, 25.6098, 92.0103)
# 0_D <- 35_BMI 2.0_P (13.7733, 62.5, 101.073)
# 2.0_P <- 35_BMI 0_D (14.2037, 60.6061, 132.008)
# 35_BMI <- 2.0_P 0_D (33.8594, 25.4237, 91.342)
# 0.0_F <- 35_BMI 2.0_P (13.7733, 60.4167, 91.7438)
# 2.0_P <- 35_BMI 0.0_F (16.6428, 50, 108.906)
# 35_BMI <- 2.0_P 0.0_F (29.4118, 28.2927, 101.649)
# 0.0_F <- 35_BMI 20_A 0_D (10.33, 69.4444, 105.453)
# 20_A <- 35_BMI 0_D 0.0_F (10.33, 69.4444, 127.712)
# 0_D <- 35_BMI 20_A (15.0646, 68.5714, 110.892)
# 20_A <- 35_BMI 0_D (14.2037, 72.7273, 133.749)
# 0.0_F <- 35_BMI 20_A (15.0646, 60.9524, 92.5573)
# 20_A <- 35_BMI 0.0_F (16.6428, 55.1724, 101.465)
# 0.0_F <- 35_BMI 0_D (14.2037, 72.7273, 110.438)
# 0_D <- 35_BMI 0.0_F (16.6428, 62.069, 100.376)
# 1_D <- 0.5_F 70_B (11.1908, 48.7179, 127.656)
# 70_B <- 0.5_F 1_D (13.9168, 39.1753, 104.617)
# 0.5_F <- 70_B 1_D (15.495, 35.1852, 116.781)
# 70_B <- 0.5_F 2.0_P 20_A (12.4821, 25.2874, 67.5298)
# 0.5_F <- 70_B 2.0_P 20_A (11.4778, 27.5, 91.2738)
# 70_B <- 0.5_F 2.0_P 0_D (10.33, 29.1667, 77.8895)
# 0.5_F <- 70_B 2.0_P 0_D (10.33, 29.1667, 96.8056)
# 2.0_P <- 0.5_F 70_B (11.1908, 37.1795, 80.9816)
# 70_B <- 0.5_F 2.0_P (15.0646, 27.619, 73.7566)
# 0.5_F <- 70_B 2.0_P (14.4907, 28.7129, 95.2994)
# 70_B <- 0.5_F 20_A 0_D (11.4778, 28.75, 76.7768)
# 0.5_F <- 70_B 20_A 0_D (12.769, 25.8427, 85.7731)
# 20_A <- 0.5_F 70_B (11.1908, 39.7436, 73.0905)
# 70_B <- 0.5_F 20_A (16.0689, 27.6786, 73.9156)
# 0.5_F <- 70_B 20_A (17.0732, 26.0504, 86.4626)
# 0.5_F <- 70_B 25_BMI 0_D (12.4821, 28.7356, 95.3749)
# 25_BMI <- 0.5_F 70_B (11.1908, 58.9744, 108.171)
# 70_B <- 0.5_F 25_BMI (16.3558, 40.3509, 107.757)
# 0.5_F <- 70_B 25_BMI (21.2339, 31.0811, 103.16)
# 0_D <- 0.5_F 70_B (11.1908, 51.2821, 82.9318)
# 70_B <- 0.5_F 0_D (16.2123, 35.3982, 94.5309)
# 0.5_F <- 70_B 0_D (21.9512, 26.1438, 86.7725)
# 2.0_P <- 0.5_F 1_D (13.9168, 34.0206, 74.1012)
# 1_D <- 0.5_F 2.0_P (15.0646, 31.4286, 82.3523)
# 0.5_F <- 1_D 2.0_P (12.0516, 39.2857, 130.391)
# 20_A <- 0.5_F 1_D (13.9168, 32.9897, 60.6697)
# 1_D <- 0.5_F 20_A (16.0689, 28.5714, 74.8657)
# 0.5_F <- 1_D 20_A (11.9082, 38.5542, 127.963)
# 25_BMI <- 0.5_F 1_D (13.9168, 50.5155, 92.656)
# 1_D <- 0.5_F 25_BMI (16.3558, 42.9825, 112.627)
# 0.5_F <- 1_D 25_BMI (20.5165, 34.2657, 113.73)
# 0.5_F <- 2.0_P 20_A 25_BMI 0_D (15.6385, 34.8624, 115.71)
# 25_BMI <- 0.5_F 2.0_P 20_A (12.4821, 52.8736, 96.9812)
# 0.5_F <- 2.0_P 20_A 25_BMI (18.0775, 36.5079, 121.172)
# 0_D <- 0.5_F 2.0_P 20_A (12.4821, 75.8621, 122.682)
# 20_A <- 0.5_F 2.0_P 0_D (10.33, 91.6667, 168.58)
# 2.0_P <- 0.5_F 20_A 0_D (11.4778, 82.5, 179.695)
# 0.5_F <- 2.0_P 20_A 0_D (30.99, 30.5556, 101.415)
# 20_A <- 0.5_F 2.0_P (15.0646, 82.8571, 152.378)
# 2.0_P <- 0.5_F 20_A (16.0689, 77.6786, 169.194)
# 0.5_F <- 2.0_P 20_A (37.8766, 32.9545, 109.378)
# 25_BMI <- 0.5_F 2.0_P 0_D (10.33, 56.9444, 104.448)
# 0.5_F <- 2.0_P 25_BMI 0_D (17.3601, 33.8843, 112.464)
# 25_BMI <- 0.5_F 2.0_P (15.0646, 54.2857, 99.5714)
# 2.0_P <- 0.5_F 25_BMI (16.3558, 50, 108.906)
# 0.5_F <- 2.0_P 25_BMI (22.6686, 36.0759, 119.738)
# 0_D <- 0.5_F 2.0_P (15.0646, 68.5714, 110.892)
# 2.0_P <- 0.5_F 0_D (16.2123, 63.7168, 138.783)
# 0.5_F <- 2.0_P 0_D (33.8594, 30.5085, 101.259)
# 25_BMI <- 0.5_F 20_A 0_D (11.4778, 57.5, 105.467)
# 0.5_F <- 20_A 25_BMI 0_D (22.3816, 29.4872, 97.8694)
# 25_BMI <- 0.5_F 20_A (16.0689, 53.5714, 98.2613)
# 20_A <- 0.5_F 25_BMI (16.3558, 52.6316, 96.7921)
# 0.5_F <- 20_A 25_BMI (28.1205, 30.6122, 101.603)
# 0_D <- 0.5_F 20_A (16.0689, 71.4286, 115.512)
# 20_A <- 0.5_F 0_D (16.2123, 70.7965, 130.198)
# 0.5_F <- 20_A 0_D (42.4677, 27.027, 89.704)
# 0_D <- 0.5_F 25_BMI (16.3558, 57.0175, 92.207)
# 25_BMI <- 0.5_F 0_D (16.2123, 57.5221, 105.508)
# 0.5_F <- 25_BMI 0_D (34.0029, 27.4262, 91.0287)
# 2.0_P <- 70_B 1_D (15.495, 26.8519, 58.4867)
# 1_D <- 70_B 2.0_P (14.4907, 28.7129, 75.2364)
# 70_B <- 1_D 2.0_P (12.0516, 34.5238, 92.1958)
# 20_A <- 70_B 1_D (15.495, 27.7778, 51.0847)
# 1_D <- 70_B 20_A (17.0732, 25.2101, 66.058)
# 70_B <- 1_D 20_A (11.9082, 36.1446, 96.524)
# 1_D <- 70_B 25_BMI 0.0_F (13.9168, 36.0825, 94.5469)
# 70_B <- 1_D 25_BMI 0.0_F (11.3343, 44.3038, 118.313)
# 25_BMI <- 70_B 1_D (15.495, 56.4815, 103.599)
# 1_D <- 70_B 25_BMI (21.2339, 41.2162, 107.999)
# 70_B <- 1_D 25_BMI (20.5165, 42.6573, 113.916)
# 0.0_F <- 70_B 1_D (15.495, 53.7037, 81.5501)
# 1_D <- 70_B 0.0_F (24.5337, 33.9181, 88.8757)
# 70_B <- 1_D 0.0_F (20.2296, 41.1348, 109.85)
# 70_B <- 2.0_P 20_A 25_BMI 0_D 0.0_F (10.1865, 36.6197, 97.7929)
# 70_B <- 2.0_P 20_A 25_BMI 0_D (15.6385, 34.8624, 93.0999)
# 70_B <- 2.0_P 20_A 25_BMI 0.0_F (11.1908, 39.7436, 106.135)
# 25_BMI <- 70_B 2.0_P 20_A (11.4778, 55, 100.882)
# 70_B <- 2.0_P 20_A 25_BMI (18.0775, 34.9206, 93.2555)
# 70_B <- 2.0_P 20_A 0_D 0.0_F (21.5208, 30.6667, 81.8953)
# 0_D <- 70_B 2.0_P 20_A (11.4778, 80, 129.374)
# 20_A <- 70_B 2.0_P 0_D (10.33, 88.8889, 163.471)
# 2.0_P <- 70_B 20_A 0_D (12.769, 71.9101, 156.629)
# 70_B <- 2.0_P 20_A 0_D (30.99, 29.6296, 79.1259)
# 0.0_F <- 70_B 2.0_P 20_A (11.4778, 68.75, 104.398)
# 2.0_P <- 70_B 20_A 0.0_F (12.0516, 65.4762, 142.615)
# 70_B <- 2.0_P 20_A 0.0_F (24.5337, 32.1637, 85.8932)
# 20_A <- 70_B 2.0_P (14.4907, 79.2079, 145.667)
# 2.0_P <- 70_B 20_A (17.0732, 67.2269, 146.429)
# 70_B <- 2.0_P 20_A (37.8766, 30.303, 80.9242)
# 70_B <- 2.0_P 25_BMI 0_D 0.0_F (11.4778, 33.75, 90.1293)
# 25_BMI <- 70_B 2.0_P 0_D (10.33, 56.9444, 104.448)
# 2.0_P <- 70_B 25_BMI 0_D (12.4821, 47.1264, 102.647)
# 70_B <- 2.0_P 25_BMI 0_D (17.3601, 33.8843, 90.488)
# 2.0_P <- 70_B 25_BMI 0.0_F (13.9168, 35.0515, 76.3466)
# 70_B <- 2.0_P 25_BMI 0.0_F (14.0603, 34.6939, 92.6499)
# 25_BMI <- 70_B 2.0_P (14.4907, 51.4851, 94.4346)
# 2.0_P <- 70_B 25_BMI (21.2339, 35.1351, 76.5287)
# 70_B <- 2.0_P 25_BMI (22.6686, 32.9114, 87.8898)
# 0.0_F <- 70_B 2.0_P 0_D (10.33, 70.8333, 107.562)
# 2.0_P <- 70_B 0_D 0.0_F (16.2123, 45.1327, 98.3048)
# 70_B <- 2.0_P 0_D 0.0_F (23.5294, 31.0976, 83.046)
# 0_D <- 70_B 2.0_P (14.4907, 71.2871, 115.283)
# 2.0_P <- 70_B 0_D (21.9512, 47.0588, 102.5)
# 70_B <- 2.0_P 0_D (33.8594, 30.5085, 81.4728)
# 0.0_F <- 70_B 2.0_P (14.4907, 66.3366, 100.733)
# 2.0_P <- 70_B 0.0_F (24.5337, 39.1813, 85.3417)
# 70_B <- 2.0_P 0.0_F (29.4118, 32.6829, 87.2797)
# 70_B <- 20_A 25_BMI 0_D 0.0_F (15.7819, 33.6364, 89.8258)
# 25_BMI <- 70_B 20_A 0_D (12.769, 57.3034, 105.106)
# 20_A <- 70_B 25_BMI 0_D (12.4821, 58.6207, 107.806)
# 70_B <- 20_A 25_BMI 0_D (22.3816, 32.6923, 87.3047)
# 25_BMI <- 70_B 20_A 0.0_F (12.0516, 58.3333, 106.996)
# 20_A <- 70_B 25_BMI 0.0_F (13.9168, 50.5155, 92.9005)
# 70_B <- 20_A 25_BMI 0.0_F (18.9383, 37.1212, 99.1321)
# 25_BMI <- 70_B 20_A (17.0732, 57.1429, 104.812)
# 20_A <- 70_B 25_BMI (21.2339, 45.9459, 84.4969)
# 70_B <- 20_A 25_BMI (28.1205, 34.6939, 92.6499)
# 0.0_F <- 70_B 20_A 0_D (12.769, 74.1573, 112.609)
# 0_D <- 70_B 20_A 0.0_F (12.0516, 78.5714, 127.063)
# 20_A <- 70_B 0_D 0.0_F (16.2123, 58.4071, 107.414)
# 70_B <- 20_A 0_D 0.0_F (30.99, 30.5556, 81.5986)
# 0_D <- 70_B 20_A (17.0732, 74.7899, 120.948)
# 20_A <- 70_B 0_D (21.9512, 58.1699, 106.977)
# 70_B <- 20_A 0_D (42.4677, 30.0676, 80.2954)
# 0.0_F <- 70_B 20_A (17.0732, 70.5882, 107.19)
# 20_A <- 70_B 0.0_F (24.5337, 49.1228, 90.3393)
# 70_B <- 20_A 0.0_F (37.0158, 32.5581, 86.9464)
# 0.0_F <- 70_B 25_BMI 0_D (12.4821, 71.2644, 108.216)
# 0_D <- 70_B 25_BMI 0.0_F (13.9168, 63.9175, 103.365)
# 25_BMI <- 70_B 0_D 0.0_F (16.2123, 54.8673, 100.638)
# 70_B <- 25_BMI 0_D 0.0_F (24.6772, 36.0465, 96.2621)
# 0_D <- 70_B 25_BMI (21.2339, 58.7838, 95.0633)
# 25_BMI <- 70_B 0_D (21.9512, 56.8627, 104.298)
# 70_B <- 25_BMI 0_D (34.0029, 36.7089, 98.0309)
# 0.0_F <- 70_B 25_BMI (21.2339, 65.5405, 99.5245)
# 25_BMI <- 70_B 0.0_F (24.5337, 56.7251, 104.046)
# 70_B <- 25_BMI 0.0_F (36.0115, 38.6454, 103.203)
# 0.0_F <- 70_B 0_D (21.9512, 73.8562, 112.152)
# 0_D <- 70_B 0.0_F (24.5337, 66.0819, 106.866)
# 70_B <- 0_D 0.0_F (45.6241, 35.5346, 94.8951)
# 20_A <- 1_D 2.0_P (12.0516, 57.1429, 105.089)
# 2.0_P <- 1_D 20_A (11.9082, 57.8313, 125.964)
# 25_BMI <- 1_D 2.0_P (12.0516, 44.0476, 80.7926)
# 2.0_P <- 1_D 25_BMI (20.5165, 25.8741, 56.3571)
# 0.0_F <- 1_D 2.0_P (12.0516, 48.8095, 74.1182)
# 2.0_P <- 1_D 0.0_F (20.2296, 29.078, 63.3355)
# 20_A <- 1_D 25_BMI 0.0_F (11.3343, 27.8481, 51.2141)
# 25_BMI <- 1_D 20_A (11.9082, 48.1928, 88.3957)
# 20_A <- 1_D 25_BMI (20.5165, 27.972, 51.442)
# 0.0_F <- 1_D 20_A (11.9082, 50.6024, 76.8407)
# 20_A <- 1_D 0.0_F (20.2296, 29.7872, 54.7802)
# 0.0_F <- 1_D 25_BMI (20.5165, 55.2448, 83.8902)
# 25_BMI <- 1_D 0.0_F (20.2296, 56.0284, 102.768)
# 1_D <- 25_BMI 0.0_F (36.0115, 31.4741, 82.4716)
# 0.0_F <- 2.0_P 20_A 25_BMI 0_D (15.6385, 65.1376, 98.9127)
# 0_D <- 2.0_P 20_A 25_BMI 0.0_F (11.1908, 91.0256, 147.204)
# 25_BMI <- 2.0_P 20_A 0_D 0.0_F (21.5208, 47.3333, 86.8193)
# 20_A <- 2.0_P 25_BMI 0_D 0.0_F (11.4778, 88.75, 163.216)
# 2.0_P <- 20_A 25_BMI 0_D 0.0_F (15.7819, 64.5455, 140.588)
# 0_D <- 2.0_P 20_A 25_BMI (18.0775, 86.5079, 139.898)
# 25_BMI <- 2.0_P 20_A 0_D (30.99, 50.463, 92.5597)
# 20_A <- 2.0_P 25_BMI 0_D (17.3601, 90.0826, 165.666)
# 2.0_P <- 20_A 25_BMI 0_D (22.3816, 69.8718, 152.19)
# 0.0_F <- 2.0_P 20_A 25_BMI (18.0775, 61.9048, 94.0035)
# 25_BMI <- 2.0_P 20_A 0.0_F (24.5337, 45.614, 83.6657)
# 20_A <- 2.0_P 25_BMI 0.0_F (14.0603, 79.5918, 146.373)
# 2.0_P <- 20_A 25_BMI 0.0_F (18.9383, 59.0909, 128.707)
# 25_BMI <- 2.0_P 20_A (37.8766, 47.7273, 87.5419)
# 20_A <- 2.0_P 25_BMI (22.6686, 79.7468, 146.658)
# 2.0_P <- 20_A 25_BMI (28.1205, 64.2857, 140.022)
# 0.0_F <- 2.0_P 20_A 0_D (30.99, 69.4444, 105.453)
# 0_D <- 2.0_P 20_A 0.0_F (24.5337, 87.7193, 141.857)
# 20_A <- 2.0_P 0_D 0.0_F (23.5294, 91.4634, 168.206)
# 2.0_P <- 20_A 0_D 0.0_F (30.99, 69.4444, 151.259)
# 0_D <- 2.0_P 20_A (37.8766, 81.8182, 132.314)
# 20_A <- 2.0_P 0_D (33.8594, 91.5254, 168.32)
# 2.0_P <- 20_A 0_D (42.4677, 72.973, 158.944)
# 0.0_F <- 2.0_P 20_A (37.8766, 64.7727, 98.3586)
# 20_A <- 2.0_P 0.0_F (29.4118, 83.4146, 153.404)
# 2.0_P <- 20_A 0.0_F (37.0158, 66.2791, 144.364)
# 0.0_F <- 2.0_P 25_BMI 0_D (17.3601, 66.1157, 100.398)
# 0_D <- 2.0_P 25_BMI 0.0_F (14.0603, 81.6327, 132.014)
# 25_BMI <- 2.0_P 0_D 0.0_F (23.5294, 48.7805, 89.4737)
# 2.0_P <- 25_BMI 0_D 0.0_F (24.6772, 46.5116, 101.308)
# 0_D <- 2.0_P 25_BMI (22.6686, 76.5823, 123.847)
# 25_BMI <- 2.0_P 0_D (33.8594, 51.2712, 94.0421)
# 2.0_P <- 25_BMI 0_D (34.0029, 51.0549, 111.204)
# 0.0_F <- 2.0_P 25_BMI (22.6686, 62.0253, 94.1866)
# 25_BMI <- 2.0_P 0.0_F (29.4118, 47.8049, 87.6842)
# 2.0_P <- 25_BMI 0.0_F (36.0115, 39.0438, 85.0423)
# 0.0_F <- 2.0_P 0_D (33.8594, 69.4915, 105.524)
# 0_D <- 2.0_P 0.0_F (29.4118, 80, 129.374)
# 2.0_P <- 0_D 0.0_F (45.6241, 51.5723, 112.331)
# 0.0_F <- 20_A 25_BMI 0_D (22.3816, 70.5128, 107.075)
# 0_D <- 20_A 25_BMI 0.0_F (18.9383, 83.3333, 134.764)
# 25_BMI <- 20_A 0_D 0.0_F (30.99, 50.9259, 93.4089)
# 20_A <- 25_BMI 0_D 0.0_F (24.6772, 63.9535, 117.614)
# 0_D <- 20_A 25_BMI (28.1205, 79.5918, 128.713)
# 25_BMI <- 20_A 0_D (42.4677, 52.7027, 96.6679)
# 20_A <- 25_BMI 0_D (34.0029, 65.8228, 121.051)
# 0.0_F <- 20_A 25_BMI (28.1205, 67.3469, 102.268)
# 25_BMI <- 20_A 0.0_F (37.0158, 51.1628, 93.8433)
# 20_A <- 25_BMI 0.0_F (36.0115, 52.5896, 96.715)
# 0.0_F <- 20_A 0_D (42.4677, 72.973, 110.811)
# 0_D <- 20_A 0.0_F (37.0158, 83.7209, 135.391)
# 20_A <- 0_D 0.0_F (45.6241, 67.9245, 124.917)
# 0.0_F <- 25_BMI 0_D (34.0029, 72.5738, 110.205)
# 0_D <- 25_BMI 0.0_F (36.0115, 68.5259, 110.818)
# 25_BMI <- 0_D 0.0_F (45.6241, 54.0881, 99.2089)
# 595
# ['90_G', '0_D'] --> 15_BMI  lift 226.811  conf 30.2632
# ['15_BMI', '0_D'] --> 90_G  lift 219.302  conf 26.7442
# ['15_BMI', '0.0_F'] --> 90_G  lift 213.425  conf 26.0274
# ['90_G', '0_D'] --> 5.0_P  lift 104.104  conf 27.6316
# ['60_B', '2.0_P', '20_A', '0_D'] --> 90_G  lift 218.667  conf 26.6667
# ['90_G', '0_D'] --> 60_B  lift 148.72  conf 39.4737
# ['90_G', '0_D'] --> 0.5_F  lift 82.9762  conf 25.0
# ['90_G', '0_D'] --> 70_B  lift 87.8453  conf 32.8947
# ['90_G', '0_D'] --> 2.0_P  lift 120.37  conf 55.2632
# ['90_G', '0_D'] --> 20_A  lift 137.929  conf 75.0
# ['90_G', '0_D'] --> 25_BMI  lift 86.8837  conf 47.3684
# ['90_G', '0_D'] --> 0.0_F  lift 113.889  conf 75.0
# ['15_BMI', '0.0_F'] --> 5.0_P  lift 103.221  conf 27.3973
# ['60_B', '2.0_P', '20_A', '0_D'] --> 15_BMI  lift 209.849  conf 28.0
# ['60_B', '2.0_P', '0_D'] --> 15_BMI  lift 203.558  conf 27.1605
# ['60_B', '20_A', '0_D', '0.0_F'] --> 15_BMI  lift 227.685  conf 30.3797
# ['60_B', '20_A', '0_D'] --> 15_BMI  lift 196.461  conf 26.2136
# ['60_B', '20_A', '0.0_F'] --> 15_BMI  lift 211.613  conf 28.2353
# ['60_B', '0_D', '0.0_F'] --> 15_BMI  lift 219.539  conf 29.2929
# ['15_BMI', '0_D'] --> 60_B  lift 144.569  conf 38.3721
# ['60_B', '0_D'] --> 15_BMI  lift 188.796  conf 25.1908
# ['15_BMI', '0.0_F'] --> 60_B  lift 154.832  conf 41.0959
# ['15_BMI', '0_D'] --> 70_B  lift 71.4203  conf 26.7442
# ['15_BMI', '0.0_F'] --> 70_B  lift 69.5061  conf 26.0274
# ['2.0_P', '20_A', '0_D', '0.0_F'] --> 15_BMI  lift 194.86  conf 26.0
# ['15_BMI', '0_D'] --> 2.0_P  lift 126.635  conf 58.1395
# ['15_BMI', '0.0_F'] --> 2.0_P  lift 119.349  conf 54.7945
# ['20_A', '0_D', '0.0_F'] --> 15_BMI  lift 187.366  conf 25.0
# ['15_BMI', '0_D'] --> 20_A  lift 134.721  conf 73.2558
# ['15_BMI', '0.0_F'] --> 20_A  lift 136.039  conf 73.9726
# ['15_BMI', '0_D'] --> 0.0_F  lift 120.069  conf 79.0698
# ['15_BMI', '0.0_F'] --> 0_D  lift 150.64  conf 93.1507
# ['40_A', '0.0_F'] --> 8.0_P  lift 216.228  conf 38.1579
# ['8.0_P', '0.0_F'] --> 40_A  lift 244.473  conf 37.1795
# ['35_BMI', '1_D'] --> 40_A  lift 179.96  conf 27.3684
# ['40_A', '0.0_F'] --> 35_BMI  lift 104.002  conf 28.9474
# ['40_A', '0.0_F'] --> 70_B  lift 105.414  conf 39.4737
# ['1_D', '25_BMI', '0.0_F'] --> 40_A  lift 191.438  conf 29.1139
# ['40_A', '0.0_F'] --> 1_D  lift 144.806  conf 55.2632
# ['1_D', '0.0_F'] --> 40_A  lift 195.865  conf 29.7872
# ['40_A', '0.0_F'] --> 25_BMI  lift 106.191  conf 57.8947
# ['40_A', '0.0_F'] --> 0_D  lift 72.3471  conf 44.7368
# ['100_G', '20_A'] --> 60_B  lift 153.887  conf 40.8451
# ['100_G', '0_D'] --> 60_B  lift 114.865  conf 30.4878
# ['0.5_F', '2.0_P', '0_D'] --> 100_G  lift 158.409  conf 25.0
# ['100_G', '20_A'] --> 0.5_F  lift 121.543  conf 36.6197
# ['100_G', '0_D'] --> 0.5_F  lift 101.19  conf 30.4878
# ['100_G', '20_A'] --> 70_B  lift 71.464  conf 26.7606
# ['100_G', '0_D'] --> 70_B  lift 87.931  conf 32.9268
# ['2.0_P', '20_A', '25_BMI', '0_D', '0.0_F'] --> 100_G  lift 160.64  conf 25.3521
# ['100_G', '20_A'] --> 2.0_P  lift 168.728  conf 77.4648
# ['2.0_P', '25_BMI', '0_D', '0.0_F'] --> 100_G  lift 158.409  conf 25.0
# ['100_G', '0_D'] --> 2.0_P  lift 148.75  conf 68.2927
# ['100_G', '20_A'] --> 25_BMI  lift 103.336  conf 56.338
# ['100_G', '20_A'] --> 0_D  lift 141.218  conf 87.3239
# ['100_G', '0_D'] --> 20_A  lift 139.05  conf 75.6098
# ['100_G', '20_A'] --> 0.0_F  lift 96.2441  conf 63.3803
# ['100_G', '0_D'] --> 25_BMI  lift 93.9474  conf 51.2195
# ['100_G', '0_D'] --> 0.0_F  lift 105.556  conf 69.5122
# ['30_A', '70_B'] --> 8.0_P  lift 173.148  conf 30.5556
# ['30_A', '1_D'] --> 8.0_P  lift 158.667  conf 28.0
# ['30_A', '25_BMI'] --> 8.0_P  lift 172.982  conf 30.5263
# ['30_A', '0_D'] --> 8.0_P  lift 154.545  conf 27.2727
# ['8.0_P', '0.0_F'] --> 30_A  lift 129.335  conf 28.2051
# ['0.5_F', '70_B'] --> 8.0_P  lift 159.829  conf 28.2051
# ['8.0_P', '0.0_F'] --> 70_B  lift 102.711  conf 38.4615
# ['1_D', '25_BMI', '0.0_F'] --> 8.0_P  lift 157.806  conf 27.8481
# ['1_D', '25_BMI'] --> 8.0_P  lift 142.657  conf 25.1748
# ['8.0_P', '0.0_F'] --> 1_D  lift 124.296  conf 47.4359
# ['1_D', '0.0_F'] --> 8.0_P  lift 148.7  conf 26.2411
# ['8.0_P', '0.0_F'] --> 25_BMI  lift 105.82  conf 57.6923
# ['8.0_P', '0.0_F'] --> 0_D  lift 85.0051  conf 52.5641
# ['80_B', '0.0_F'] --> 5.0_P  lift 123.865  conf 32.8767
# ['35_BMI', '1_D'] --> 80_B  lift 139.749  conf 25.2632
# ['35_BMI', '0_D', '0.0_F'] --> 80_B  lift 145.977  conf 26.3889
# ['35_BMI', '0_D'] --> 80_B  lift 145.278  conf 26.2626
# ['80_B', '0.0_F'] --> 35_BMI  lift 137.805  conf 38.3562
# ['80_B', '0.0_F'] --> 1_D  lift 100.505  conf 38.3562
# ['80_B', '0.0_F'] --> 2.0_P  lift 80.5608  conf 36.9863
# ['80_B', '0.0_F'] --> 20_A  lift 85.6544  conf 46.5753
# ['80_B', '0.0_F'] --> 25_BMI  lift 87.9416  conf 47.9452
# ['80_B', '0.0_F'] --> 0_D  lift 99.6885  conf 61.6438
# ['30_A', '70_B'] --> 5.0_P  lift 146.517  conf 38.8889
# ['5.0_P', '70_B'] --> 30_A  lift 166.746  conf 36.3636
# ['30_A', '1_D'] --> 5.0_P  lift 120.562  conf 32.0
# ['5.0_P', '1_D'] --> 30_A  lift 155.004  conf 33.8028
# ['5.0_P', '25_BMI', '0_D'] --> 30_A  lift 157.218  conf 34.2857
# ['5.0_P', '25_BMI', '0.0_F'] --> 30_A  lift 149.168  conf 32.5301
# ['30_A', '25_BMI'] --> 5.0_P  lift 150.703  conf 40.0
# ['5.0_P', '25_BMI'] --> 30_A  lift 154.204  conf 33.6283
# ['5.0_P', '0_D', '0.0_F'] --> 30_A  lift 139.979  conf 30.5263
# ['30_A', '0_D'] --> 5.0_P  lift 181.039  conf 48.0519
# ['5.0_P', '0_D'] --> 30_A  lift 148.828  conf 32.4561
# ['30_A', '0.0_F'] --> 5.0_P  lift 178.464  conf 47.3684
# ['5.0_P', '0.0_F'] --> 30_A  lift 149.528  conf 32.6087
# ['30_A', '70_B'] --> 35_BMI  lift 99.7995  conf 27.7778
# ['35_BMI', '70_B'] --> 30_A  lift 123.933  conf 27.027
# ['30_A', '1_D'] --> 35_BMI  lift 100.598  conf 28.0
# ['30_A', '70_B'] --> 0.5_F  lift 101.415  conf 30.5556
# ['0.5_F', '70_B'] --> 30_A  lift 129.335  conf 28.2051
# ['30_A', '1_D'] --> 0.5_F  lift 123.911  conf 37.3333
# ['0.5_F', '1_D'] --> 30_A  lift 132.366  conf 28.866
# ['30_A', '25_BMI'] --> 0.5_F  lift 101.318  conf 30.5263
# ['0.5_F', '25_BMI'] --> 30_A  lift 116.649  conf 25.4386
# ['30_A', '0_D'] --> 0.5_F  lift 86.209  conf 25.974
# ['30_A', '70_B'] --> 1_D  lift 134.654  conf 51.3889
# ['30_A', '1_D'] --> 70_B  lift 131.745  conf 49.3333
# ['70_B', '1_D'] --> 30_A  lift 157.097  conf 34.2593
# ['70_B', '25_BMI', '0_D'] --> 30_A  lift 121.227  conf 26.4368
# ['70_B', '25_BMI', '0.0_F'] --> 30_A  lift 137.093  conf 29.8969
# ['30_A', '70_B'] --> 25_BMI  lift 119.733  conf 65.2778
# ['30_A', '25_BMI'] --> 70_B  lift 132.119  conf 49.4737
# ['70_B', '25_BMI'] --> 30_A  lift 145.621  conf 31.7568
# ['30_A', '70_B'] --> 0_D  lift 78.6124  conf 48.6111
# ['30_A', '0_D'] --> 70_B  lift 121.386  conf 45.4545
# ['30_A', '70_B'] --> 0.0_F  lift 97.0165  conf 63.8889
# ['30_A', '0.0_F'] --> 70_B  lift 129.308  conf 48.4211
# ['70_B', '0.0_F'] --> 30_A  lift 123.353  conf 26.9006
# ['30_A', '1_D'] --> 2.0_P  lift 55.1792  conf 25.3333
# ['1_D', '25_BMI', '0.0_F'] --> 30_A  lift 139.307  conf 30.3797
# ['30_A', '1_D'] --> 25_BMI  lift 112.498  conf 61.3333
# ['30_A', '25_BMI'] --> 1_D  lift 126.878  conf 48.4211
# ['1_D', '25_BMI'] --> 30_A  lift 147.506  conf 32.1678
# ['30_A', '1_D'] --> 0.0_F  lift 76.9383  conf 50.6667
# ['30_A', '0.0_F'] --> 1_D  lift 104.812  conf 40.0
# ['1_D', '0.0_F'] --> 30_A  lift 123.582  conf 26.9504
# ['30_A', '25_BMI'] --> 0_D  lift 83.4119  conf 51.5789
# ['30_A', '0_D'] --> 25_BMI  lift 116.722  conf 63.6364
# ['30_A', '25_BMI'] --> 0.0_F  lift 97.5049  conf 64.2105
# ['30_A', '0.0_F'] --> 25_BMI  lift 117.776  conf 64.2105
# ['30_A', '0_D'] --> 0.0_F  lift 112.41  conf 74.026
# ['30_A', '0.0_F'] --> 0_D  lift 97.0302  conf 60.0
# ['60_B', '20_A', '0_D', '0.0_F'] --> 5.0_P  lift 104.92  conf 27.8481
# ['5.0_P', '20_A', '0.0_F'] --> 60_B  lift 123.865  conf 32.8767
# ['60_B', '20_A', '0.0_F'] --> 5.0_P  lift 106.378  conf 28.2353
# ['5.0_P', '20_A'] --> 60_B  lift 117.736  conf 31.25
# ['5.0_P', '25_BMI', '0_D'] --> 60_B  lift 113.027  conf 30.0
# ['60_B', '25_BMI', '0_D'] --> 5.0_P  lift 111.435  conf 29.5775
# ['5.0_P', '25_BMI', '0.0_F'] --> 60_B  lift 104.402  conf 27.7108
# ['60_B', '25_BMI', '0.0_F'] --> 5.0_P  lift 117.1  conf 31.0811
# ['5.0_P', '25_BMI'] --> 60_B  lift 100.024  conf 26.5487
# ['60_B', '25_BMI'] --> 5.0_P  lift 107.645  conf 28.5714
# ['5.0_P', '0_D', '0.0_F'] --> 60_B  lift 103.112  conf 27.3684
# ['60_B', '0_D', '0.0_F'] --> 5.0_P  lift 98.9462  conf 26.2626
# ['5.0_P', '0_D'] --> 60_B  lift 102.451  conf 27.193
# ['60_B', '0.0_F'] --> 5.0_P  lift 100.076  conf 26.5625
# ['5.0_P', '1_D'] --> 35_BMI  lift 111.326  conf 30.9859
# ['35_BMI', '0_D', '0.0_F'] --> 5.0_P  lift 94.1892  conf 25.0
# ['35_BMI', '0.0_F'] --> 5.0_P  lift 97.4371  conf 25.8621
# ['5.0_P', '1_D'] --> 0.5_F  lift 93.4943  conf 28.169
# ['5.0_P', '70_B'] --> 1_D  lift 115.702  conf 44.1558
# ['5.0_P', '1_D'] --> 70_B  lift 127.883  conf 47.8873
# ['70_B', '1_D'] --> 5.0_P  lift 118.609  conf 31.4815
# ['5.0_P', '20_A', '0.0_F'] --> 70_B  lift 87.7972  conf 32.8767
# ['70_B', '20_A', '0.0_F'] --> 5.0_P  lift 107.645  conf 28.5714
# ['5.0_P', '70_B'] --> 20_A  lift 76.4281  conf 41.5584
# ['5.0_P', '20_A'] --> 70_B  lift 89.0166  conf 33.3333
# ['70_B', '20_A'] --> 5.0_P  lift 101.313  conf 26.8908
# ['5.0_P', '25_BMI', '0_D'] --> 70_B  lift 91.5599  conf 34.2857
# ['70_B', '25_BMI', '0_D'] --> 5.0_P  lift 103.933  conf 27.5862
# ['5.0_P', '25_BMI', '0.0_F'] --> 70_B  lift 106.176  conf 39.759
# ['70_B', '25_BMI', '0.0_F'] --> 5.0_P  lift 128.175  conf 34.0206
# ['5.0_P', '70_B'] --> 25_BMI  lift 111.958  conf 61.039
# ['5.0_P', '25_BMI'] --> 70_B  lift 111.074  conf 41.5929
# ['70_B', '25_BMI'] --> 5.0_P  lift 119.646  conf 31.7568
# ['5.0_P', '0_D', '0.0_F'] --> 70_B  lift 101.198  conf 37.8947
# ['70_B', '0_D', '0.0_F'] --> 5.0_P  lift 120.029  conf 31.8584
# ['5.0_P', '70_B'] --> 0_D  lift 90.3095  conf 55.8442
# ['5.0_P', '0_D'] --> 70_B  lift 100.729  conf 37.7193
# ['70_B', '0_D'] --> 5.0_P  lift 105.886  conf 28.1046
# ['5.0_P', '70_B'] --> 0.0_F  lift 112.41  conf 74.026
# ['5.0_P', '0.0_F'] --> 70_B  lift 110.303  conf 41.3043
# ['70_B', '0.0_F'] --> 5.0_P  lift 125.586  conf 33.3333
# ['5.0_P', '1_D'] --> 20_A  lift 77.7063  conf 42.2535
# ['5.0_P', '20_A'] --> 1_D  lift 81.8844  conf 31.25
# ['1_D', '20_A'] --> 5.0_P  lift 136.177  conf 36.1446
# ['5.0_P', '25_BMI', '0.0_F'] --> 1_D  lift 82.0817  conf 31.3253
# ['1_D', '25_BMI', '0.0_F'] --> 5.0_P  lift 123.996  conf 32.9114
# ['5.0_P', '1_D'] --> 25_BMI  lift 111.086  conf 60.5634
# ['5.0_P', '25_BMI'] --> 1_D  lift 99.7106  conf 38.0531
# ['1_D', '25_BMI'] --> 5.0_P  lift 113.29  conf 30.0699
# ['5.0_P', '1_D'] --> 0.0_F  lift 91.9666  conf 60.5634
# ['5.0_P', '0.0_F'] --> 1_D  lift 81.6471  conf 31.1594
# ['1_D', '0.0_F'] --> 5.0_P  lift 114.897  conf 30.4965
# ['20_A', '25_BMI', '0_D', '0.0_F'] --> 5.0_P  lift 116.452  conf 30.9091
# ['5.0_P', '25_BMI', '0_D'] --> 20_A  lift 107.716  conf 58.5714
# ['20_A', '25_BMI', '0_D'] --> 5.0_P  lift 99.0194  conf 26.2821
# ['5.0_P', '20_A', '0.0_F'] --> 25_BMI  lift 113.068  conf 61.6438
# ['5.0_P', '25_BMI', '0.0_F'] --> 20_A  lift 99.7075  conf 54.2169
# ['20_A', '25_BMI', '0.0_F'] --> 5.0_P  lift 128.44  conf 34.0909
# ['5.0_P', '20_A'] --> 25_BMI  lift 114.638  conf 62.5
# ['5.0_P', '25_BMI'] --> 20_A  lift 97.6487  conf 53.0973
# ['20_A', '25_BMI'] --> 5.0_P  lift 115.334  conf 30.6122
# ['5.0_P', '20_A', '0.0_F'] --> 0_D  lift 124.057  conf 76.7123
# ['5.0_P', '0_D', '0.0_F'] --> 20_A  lift 108.407  conf 58.9474
# ['20_A', '0_D', '0.0_F'] --> 5.0_P  lift 97.6777  conf 25.9259
# ['5.0_P', '20_A'] --> 0_D  lift 111.18  conf 68.75
# ['5.0_P', '0_D'] --> 20_A  lift 106.471  conf 57.8947
# ['5.0_P', '20_A'] --> 0.0_F  lift 115.471  conf 76.0417
# ['5.0_P', '0.0_F'] --> 20_A  lift 97.2831  conf 52.8986
# ['20_A', '0.0_F'] --> 5.0_P  lift 106.602  conf 28.2946
# ['5.0_P', '25_BMI', '0_D'] --> 0.0_F  lift 123.651  conf 81.4286
# ['5.0_P', '25_BMI', '0.0_F'] --> 0_D  lift 111.059  conf 68.6747
# ['5.0_P', '0_D', '0.0_F'] --> 25_BMI  lift 110.053  conf 60.0
# ['25_BMI', '0_D', '0.0_F'] --> 5.0_P  lift 124.855  conf 33.1395
# ['5.0_P', '25_BMI'] --> 0_D  lift 100.179  conf 61.9469
# ['5.0_P', '0_D'] --> 25_BMI  lift 112.627  conf 61.4035
# ['25_BMI', '0_D'] --> 5.0_P  lift 111.278  conf 29.5359
# ['5.0_P', '25_BMI'] --> 0.0_F  lift 111.537  conf 73.4513
# ['5.0_P', '0.0_F'] --> 25_BMI  lift 110.318  conf 60.1449
# ['25_BMI', '0.0_F'] --> 5.0_P  lift 124.585  conf 33.0677
# ['5.0_P', '0_D'] --> 0.0_F  lift 126.543  conf 83.3333
# ['5.0_P', '0.0_F'] --> 0_D  lift 111.327  conf 68.8406
# ['0_D', '0.0_F'] --> 5.0_P  lift 112.553  conf 29.8742
# ['60_B', '2.0_P', '20_A', '0_D'] --> 35_BMI  lift 105.388  conf 29.3333
# ['60_B', '2.0_P', '20_A'] --> 35_BMI  lift 119.759  conf 33.3333
# ['35_BMI', '2.0_P', '20_A'] --> 60_B  lift 143.072  conf 37.9747
# ['60_B', '2.0_P', '0_D'] --> 35_BMI  lift 97.5818  conf 27.1605
# ['60_B', '2.0_P'] --> 35_BMI  lift 108.132  conf 30.0971
# ['35_BMI', '2.0_P'] --> 60_B  lift 121.661  conf 32.2917
# ['60_B', '20_A', '0_D'] --> 35_BMI  lift 90.6916  conf 25.2427
# ['35_BMI', '20_A', '0_D'] --> 60_B  lift 136.051  conf 36.1111
# ['60_B', '20_A'] --> 35_BMI  lift 100.598  conf 28.0
# ['35_BMI', '20_A'] --> 60_B  lift 125.586  conf 33.3333
# ['35_BMI', '0_D'] --> 60_B  lift 98.9462  conf 26.2626
# ['60_B', '2.0_P', '20_A', '0_D'] --> 0.5_F  lift 92.9333  conf 28.0
# ['60_B', '2.0_P', '20_A'] --> 0.5_F  lift 110.635  conf 33.3333
# ['0.5_F', '2.0_P', '20_A'] --> 60_B  lift 129.916  conf 34.4828
# ['60_B', '2.0_P', '0_D'] --> 0.5_F  lift 94.2446  conf 28.3951
# ['0.5_F', '2.0_P', '0_D'] --> 60_B  lift 120.353  conf 31.9444
# ['60_B', '2.0_P'] --> 0.5_F  lift 109.561  conf 33.0097
# ['0.5_F', '2.0_P'] --> 60_B  lift 121.997  conf 32.381
# ['0.5_F', '20_A', '0_D'] --> 60_B  lift 113.027  conf 30.0
# ['60_B', '20_A'] --> 0.5_F  lift 98.2438  conf 29.6
# ['0.5_F', '20_A'] --> 60_B  lift 124.464  conf 33.0357
# ['60_B', '25_BMI', '0_D'] --> 0.5_F  lift 84.1449  conf 25.3521
# ['60_B', '25_BMI'] --> 0.5_F  lift 91.6689  conf 27.619
# ['0.5_F', '25_BMI'] --> 60_B  lift 95.8416  conf 25.4386
# ['0.5_F', '0_D'] --> 60_B  lift 106.692  conf 28.3186
# ['1_D', '2.0_P'] --> 60_B  lift 98.6744  conf 26.1905
# ['1_D', '20_A'] --> 60_B  lift 99.8632  conf 26.506
# ['60_B', '25_BMI', '0.0_F'] --> 1_D  lift 74.3599  conf 28.3784
# ['1_D', '25_BMI', '0.0_F'] --> 60_B  lift 100.151  conf 26.5823
# ['60_B', '25_BMI'] --> 1_D  lift 84.8478  conf 32.381
# ['2.0_P', '20_A', '25_BMI', '0_D', '0.0_F'] --> 60_B  lift 122.048  conf 32.3944
# ['60_B', '2.0_P', '20_A', '0_D'] --> 25_BMI  lift 78.2596  conf 42.6667
# ['2.0_P', '20_A', '25_BMI', '0_D'] --> 60_B  lift 110.607  conf 29.3578
# ['2.0_P', '20_A', '25_BMI', '0.0_F'] --> 60_B  lift 115.925  conf 30.7692
# ['60_B', '2.0_P', '20_A'] --> 25_BMI  lift 79.4825  conf 43.3333
# ['2.0_P', '20_A', '25_BMI'] --> 60_B  lift 116.615  conf 30.9524
# ['60_B', '2.0_P', '20_A', '0_D'] --> 0.0_F  lift 109.333  conf 72.0
# ['60_B', '20_A', '0_D', '0.0_F'] --> 2.0_P  lift 148.884  conf 68.3544
# ['2.0_P', '20_A', '0_D', '0.0_F'] --> 60_B  lift 135.632  conf 36.0
# ['60_B', '2.0_P', '20_A'] --> 0_D  lift 134.764  conf 83.3333
# ['60_B', '2.0_P', '0_D'] --> 20_A  lift 170.282  conf 92.5926
# ['60_B', '20_A', '0_D'] --> 2.0_P  lift 158.601  conf 72.8155
# ['2.0_P', '20_A', '0_D'] --> 60_B  lift 130.818  conf 34.7222
# ['60_B', '2.0_P', '20_A'] --> 0.0_F  lift 96.1728  conf 63.3333
# ['60_B', '20_A', '0.0_F'] --> 2.0_P  lift 146.062  conf 67.0588
# ['2.0_P', '20_A', '0.0_F'] --> 60_B  lift 125.586  conf 33.3333
# ['60_B', '2.0_P'] --> 20_A  lift 160.694  conf 87.3786
# ['60_B', '20_A'] --> 2.0_P  lift 156.825  conf 72.0
# ['2.0_P', '20_A'] --> 60_B  lift 128.44  conf 34.0909
# ['2.0_P', '25_BMI', '0_D', '0.0_F'] --> 60_B  lift 127.155  conf 33.75
# ['60_B', '2.0_P', '0_D'] --> 25_BMI  lift 83.7849  conf 45.679
# ['60_B', '25_BMI', '0_D'] --> 2.0_P  lift 113.508  conf 52.1127
# ['2.0_P', '25_BMI', '0_D'] --> 60_B  lift 115.207  conf 30.5785
# ['60_B', '25_BMI', '0.0_F'] --> 2.0_P  lift 97.1326  conf 44.5946
# ['2.0_P', '25_BMI', '0.0_F'] --> 60_B  lift 126.867  conf 33.6735
# ['60_B', '2.0_P'] --> 25_BMI  lift 89.0393  conf 48.5437
# ['60_B', '25_BMI'] --> 2.0_P  lift 103.72  conf 47.619
# ['2.0_P', '25_BMI'] --> 60_B  lift 119.227  conf 31.6456
# ['60_B', '2.0_P', '0_D'] --> 0.0_F  lift 108.733  conf 71.6049
# ['60_B', '0_D', '0.0_F'] --> 2.0_P  lift 127.607  conf 58.5859
# ['2.0_P', '0_D', '0.0_F'] --> 60_B  lift 133.243  conf 35.3659
# ['60_B', '2.0_P'] --> 0_D  lift 127.175  conf 78.6408
# ['60_B', '0_D'] --> 2.0_P  lift 134.678  conf 61.8321
# ['2.0_P', '0_D'] --> 60_B  lift 129.311  conf 34.322
# ['60_B', '2.0_P'] --> 0.0_F  lift 97.3031  conf 64.0777
# ['60_B', '0.0_F'] --> 2.0_P  lift 112.31  conf 51.5625
# ['2.0_P', '0.0_F'] --> 60_B  lift 121.297  conf 32.1951
# ['60_B', '20_A', '0_D', '0.0_F'] --> 25_BMI  lift 90.5496  conf 49.3671
# ['20_A', '25_BMI', '0_D', '0.0_F'] --> 60_B  lift 133.577  conf 35.4545
# ['60_B', '20_A', '0_D'] --> 25_BMI  lift 89.0393  conf 48.5437
# ['60_B', '25_BMI', '0_D'] --> 20_A  lift 129.511  conf 70.4225
# ['20_A', '25_BMI', '0_D'] --> 60_B  lift 120.755  conf 32.0513
# ['60_B', '20_A', '0.0_F'] --> 25_BMI  lift 92.7895  conf 50.5882
# ['60_B', '25_BMI', '0.0_F'] --> 20_A  lift 106.864  conf 58.1081
# ['20_A', '25_BMI', '0.0_F'] --> 60_B  lift 122.731  conf 32.5758
# ['60_B', '20_A'] --> 25_BMI  lift 90.9768  conf 49.6
# ['60_B', '25_BMI'] --> 20_A  lift 108.592  conf 59.0476
# ['20_A', '25_BMI'] --> 60_B  lift 119.178  conf 31.6327
# ['60_B', '20_A', '0_D'] --> 0.0_F  lift 116.469  conf 76.699
# ['60_B', '20_A', '0.0_F'] --> 0_D  lift 150.302  conf 92.9412
# ['60_B', '0_D', '0.0_F'] --> 20_A  lift 146.752  conf 79.798
# ['20_A', '0_D', '0.0_F'] --> 60_B  lift 137.795  conf 36.5741
# ['60_B', '20_A'] --> 0_D  lift 133.255  conf 82.4
# ['60_B', '0_D'] --> 20_A  lift 144.597  conf 78.626
# ['20_A', '0_D'] --> 60_B  lift 131.101  conf 34.7973
# ['60_B', '20_A'] --> 0.0_F  lift 103.259  conf 68.0
# ['60_B', '0.0_F'] --> 20_A  lift 122.124  conf 66.4062
# ['20_A', '0.0_F'] --> 60_B  lift 124.125  conf 32.9457
# ['60_B', '25_BMI', '0_D'] --> 0.0_F  lift 113.354  conf 74.6479
# ['60_B', '25_BMI', '0.0_F'] --> 0_D  lift 115.824  conf 71.6216
# ['60_B', '0_D', '0.0_F'] --> 25_BMI  lift 98.1951  conf 53.5354
# ['25_BMI', '0_D', '0.0_F'] --> 60_B  lift 116.094  conf 30.814
# ['60_B', '25_BMI'] --> 0_D  lift 109.351  conf 67.619
# ['60_B', '0_D'] --> 25_BMI  lift 99.4114  conf 54.1985
# ['25_BMI', '0_D'] --> 60_B  lift 112.868  conf 29.9578
# ['60_B', '25_BMI'] --> 0.0_F  lift 107.019  conf 70.4762
# ['60_B', '0.0_F'] --> 25_BMI  lift 106.04  conf 57.8125
# ['25_BMI', '0.0_F'] --> 60_B  lift 111.076  conf 29.4821
# ['60_B', '0_D'] --> 0.0_F  lift 114.758  conf 75.5725
# ['60_B', '0.0_F'] --> 0_D  lift 125.078  conf 77.3438
# ['0_D', '0.0_F'] --> 60_B  lift 117.292  conf 31.1321
# ['35_BMI', '70_B'] --> 0.5_F  lift 94.1892  conf 28.3784
# ['0.5_F', '70_B'] --> 35_BMI  lift 96.7288  conf 26.9231
# ['35_BMI', '1_D'] --> 0.5_F  lift 139.749  conf 42.1053
# ['0.5_F', '1_D'] --> 35_BMI  lift 148.156  conf 41.2371
# ['35_BMI', '2.0_P', '20_A'] --> 0.5_F  lift 117.637  conf 35.443
# ['0.5_F', '2.0_P', '20_A'] --> 35_BMI  lift 115.63  conf 32.1839
# ...
# ['35_BMI', '20_A', '0_D'] --> 0.5_F  lift 101.415  conf 30.5556
# ['0.5_F', '20_A', '0_D'] --> 35_BMI  lift 98.8015  conf 27.5
# ['35_BMI', '20_A'] --> 0.5_F  lift 116.957  conf 35.2381
# ['0.5_F', '20_A'] --> 35_BMI  lift 118.69  conf 33.0357
# ['35_BMI', '0_D'] --> 0.5_F  lift 90.5195  conf 27.2727
# ['35_BMI', '70_B'] --> 1_D  lift 131.015  conf 50.0
# ['35_BMI', '1_D'] --> 70_B  lift 104.009  conf 38.9474
# ['70_B', '1_D'] --> 35_BMI  lift 123.086  conf 34.2593
# ['35_BMI', '2.0_P', '20_A'] --> 70_B  lift 77.7487  conf 29.1139
# ['70_B', '2.0_P', '20_A'] --> 35_BMI  lift 103.293  conf 28.75
# ['70_B', '2.0_P', '0_D'] --> 35_BMI  lift 94.8096  conf 26.3889
# ['35_BMI', '70_B'] --> 2.0_P  lift 97.1326  conf 44.5946
# ['35_BMI', '2.0_P'] --> 70_B  lift 91.7984  conf 34.375
# ['70_B', '2.0_P'] --> 35_BMI  lift 117.388  conf 32.6733
# ['35_BMI', '20_A', '0_D'] --> 70_B  lift 81.5986  conf 30.5556
# ['70_B', '20_A', '0.0_F'] --> 35_BMI  lift 89.8196  conf 25.0
# ['35_BMI', '70_B'] --> 20_A  lift 77.0413  conf 41.8919
# ['35_BMI', '20_A'] --> 70_B  lift 78.8433  conf 29.5238
# ['70_B', '20_A'] --> 35_BMI  lift 93.5935  conf 26.0504
# ['35_BMI', '0_D', '0.0_F'] --> 70_B  lift 114.98  conf 43.0556
# ['70_B', '0_D', '0.0_F'] --> 35_BMI  lift 98.5631  conf 27.4336
# ['35_BMI', '70_B'] --> 0_D  lift 80.8585  conf 50.0
# ['35_BMI', '0_D'] --> 70_B  lift 99.8065  conf 37.3737
# ['35_BMI', '70_B'] --> 0.0_F  lift 96.4464  conf 63.5135
# ['35_BMI', '0.0_F'] --> 70_B  lift 108.201  conf 40.5172
# ['70_B', '0.0_F'] --> 35_BMI  lift 98.749  conf 27.4854
# ['35_BMI', '2.0_P', '20_A'] --> 1_D  lift 79.6041  conf 30.3797
# ['35_BMI', '1_D'] --> 2.0_P  lift 82.5395  conf 37.8947
# ['35_BMI', '2.0_P'] --> 1_D  lift 98.2613  conf 37.5
# ['1_D', '2.0_P'] --> 35_BMI  lift 153.976  conf 42.8571
# ['35_BMI', '1_D'] --> 20_A  lift 63.8828  conf 34.7368
# ['35_BMI', '20_A'] --> 1_D  lift 82.3523  conf 31.4286
# ['1_D', '20_A'] --> 35_BMI  lift 142.846  conf 39.759
# ['35_BMI', '1_D'] --> 0.0_F  lift 70.3314  conf 46.3158
# ['35_BMI', '0.0_F'] --> 1_D  lift 99.3907  conf 37.931
# ['1_D', '0.0_F'] --> 35_BMI  lift 112.115  conf 31.2057
# ['2.0_P', '20_A', '0_D', '0.0_F'] --> 35_BMI  lift 91.0172  conf 25.3333
# ['35_BMI', '2.0_P', '20_A'] --> 0_D  lift 112.588  conf 69.6203
# ['35_BMI', '20_A', '0_D'] --> 2.0_P  lift 166.385  conf 76.3889
# ['2.0_P', '20_A', '0_D'] --> 35_BMI  lift 91.4829  conf 25.463
# ['35_BMI', '2.0_P', '20_A'] --> 0.0_F  lift 92.2644  conf 60.7595
# ['2.0_P', '20_A', '0.0_F'] --> 35_BMI  lift 100.85  conf 28.0702
# ['35_BMI', '2.0_P'] --> 20_A  lift 151.339  conf 82.2917
# ['35_BMI', '20_A'] --> 2.0_P  lift 163.878  conf 75.2381
# ['2.0_P', '20_A'] --> 35_BMI  lift 107.511  conf 29.9242
# ['35_BMI', '0_D', '0.0_F'] --> 2.0_P  lift 127.057  conf 58.3333
# ['2.0_P', '0_D', '0.0_F'] --> 35_BMI  lift 92.0103  conf 25.6098
# ['35_BMI', '2.0_P'] --> 0_D  lift 101.073  conf 62.5
# ['35_BMI', '0_D'] --> 2.0_P  lift 132.008  conf 60.6061
# ['2.0_P', '0_D'] --> 35_BMI  lift 91.342  conf 25.4237
# ['35_BMI', '2.0_P'] --> 0.0_F  lift 91.7438  conf 60.4167
# ['35_BMI', '0.0_F'] --> 2.0_P  lift 108.906  conf 50.0
# ['2.0_P', '0.0_F'] --> 35_BMI  lift 101.649  conf 28.2927
# ['35_BMI', '20_A', '0_D'] --> 0.0_F  lift 105.453  conf 69.4444
# ['35_BMI', '0_D', '0.0_F'] --> 20_A  lift 127.712  conf 69.4444
# ['35_BMI', '20_A'] --> 0_D  lift 110.892  conf 68.5714
# ['35_BMI', '0_D'] --> 20_A  lift 133.749  conf 72.7273
# ['35_BMI', '20_A'] --> 0.0_F  lift 92.5573  conf 60.9524
# ['35_BMI', '0.0_F'] --> 20_A  lift 101.465  conf 55.1724
# ['35_BMI', '0_D'] --> 0.0_F  lift 110.438  conf 72.7273
# ['35_BMI', '0.0_F'] --> 0_D  lift 100.376  conf 62.069
# ['0.5_F', '70_B'] --> 1_D  lift 127.656  conf 48.7179
# ['0.5_F', '1_D'] --> 70_B  lift 104.617  conf 39.1753
# ['70_B', '1_D'] --> 0.5_F  lift 116.781  conf 35.1852
# ['0.5_F', '2.0_P', '20_A'] --> 70_B  lift 67.5298  conf 25.2874
# ['70_B', '2.0_P', '20_A'] --> 0.5_F  lift 91.2738  conf 27.5
# ['0.5_F', '2.0_P', '0_D'] --> 70_B  lift 77.8895  conf 29.1667
# ['70_B', '2.0_P', '0_D'] --> 0.5_F  lift 96.8056  conf 29.1667
# ['0.5_F', '70_B'] --> 2.0_P  lift 80.9816  conf 37.1795
# ['0.5_F', '2.0_P'] --> 70_B  lift 73.7566  conf 27.619
# ['70_B', '2.0_P'] --> 0.5_F  lift 95.2994  conf 28.7129
# ['0.5_F', '20_A', '0_D'] --> 70_B  lift 76.7768  conf 28.75
# ['70_B', '20_A', '0_D'] --> 0.5_F  lift 85.7731  conf 25.8427
# ['0.5_F', '70_B'] --> 20_A  lift 73.0905  conf 39.7436
# ['0.5_F', '20_A'] --> 70_B  lift 73.9156  conf 27.6786
# ['70_B', '20_A'] --> 0.5_F  lift 86.4626  conf 26.0504
# ['70_B', '25_BMI', '0_D'] --> 0.5_F  lift 95.3749  conf 28.7356
# ['0.5_F', '70_B'] --> 25_BMI  lift 108.171  conf 58.9744
# ['0.5_F', '25_BMI'] --> 70_B  lift 107.757  conf 40.3509
# ['70_B', '25_BMI'] --> 0.5_F  lift 103.16  conf 31.0811
# ['0.5_F', '70_B'] --> 0_D  lift 82.9318  conf 51.2821
# ['0.5_F', '0_D'] --> 70_B  lift 94.5309  conf 35.3982
# ['70_B', '0_D'] --> 0.5_F  lift 86.7725  conf 26.1438
# ['0.5_F', '1_D'] --> 2.0_P  lift 74.1012  conf 34.0206
# ['0.5_F', '2.0_P'] --> 1_D  lift 82.3523  conf 31.4286
# ['1_D', '2.0_P'] --> 0.5_F  lift 130.391  conf 39.2857
# ['0.5_F', '1_D'] --> 20_A  lift 60.6697  conf 32.9897
# ['0.5_F', '20_A'] --> 1_D  lift 74.8657  conf 28.5714
# ['1_D', '20_A'] --> 0.5_F  lift 127.963  conf 38.5542
# ['0.5_F', '1_D'] --> 25_BMI  lift 92.656  conf 50.5155
# ['0.5_F', '25_BMI'] --> 1_D  lift 112.627  conf 42.9825
# ['1_D', '25_BMI'] --> 0.5_F  lift 113.73  conf 34.2657
# ['2.0_P', '20_A', '25_BMI', '0_D'] --> 0.5_F  lift 115.71  conf 34.8624
# ['0.5_F', '2.0_P', '20_A'] --> 25_BMI  lift 96.9812  conf 52.8736
# ['2.0_P', '20_A', '25_BMI'] --> 0.5_F  lift 121.172  conf 36.5079
# ['0.5_F', '2.0_P', '20_A'] --> 0_D  lift 122.682  conf 75.8621
# ['0.5_F', '2.0_P', '0_D'] --> 20_A  lift 168.58  conf 91.6667
# ['0.5_F', '20_A', '0_D'] --> 2.0_P  lift 179.695  conf 82.5
# ['2.0_P', '20_A', '0_D'] --> 0.5_F  lift 101.415  conf 30.5556
# ['0.5_F', '2.0_P'] --> 20_A  lift 152.378  conf 82.8571
# ['0.5_F', '20_A'] --> 2.0_P  lift 169.194  conf 77.6786
# ['2.0_P', '20_A'] --> 0.5_F  lift 109.378  conf 32.9545
# ['0.5_F', '2.0_P', '0_D'] --> 25_BMI  lift 104.448  conf 56.9444
# ['2.0_P', '25_BMI', '0_D'] --> 0.5_F  lift 112.464  conf 33.8843
# ['0.5_F', '2.0_P'] --> 25_BMI  lift 99.5714  conf 54.2857
# ['0.5_F', '25_BMI'] --> 2.0_P  lift 108.906  conf 50.0
# ['2.0_P', '25_BMI'] --> 0.5_F  lift 119.738  conf 36.0759
# ['0.5_F', '2.0_P'] --> 0_D  lift 110.892  conf 68.5714
# ['0.5_F', '0_D'] --> 2.0_P  lift 138.783  conf 63.7168
# ['2.0_P', '0_D'] --> 0.5_F  lift 101.259  conf 30.5085
# ['0.5_F', '20_A', '0_D'] --> 25_BMI  lift 105.467  conf 57.5
# ['20_A', '25_BMI', '0_D'] --> 0.5_F  lift 97.8694  conf 29.4872
# ['0.5_F', '20_A'] --> 25_BMI  lift 98.2613  conf 53.5714
# ['0.5_F', '25_BMI'] --> 20_A  lift 96.7921  conf 52.6316
# ['20_A', '25_BMI'] --> 0.5_F  lift 101.603  conf 30.6122
# ['0.5_F', '20_A'] --> 0_D  lift 115.512  conf 71.4286
# ['0.5_F', '0_D'] --> 20_A  lift 130.198  conf 70.7965
# ['20_A', '0_D'] --> 0.5_F  lift 89.704  conf 27.027
# ['0.5_F', '25_BMI'] --> 0_D  lift 92.207  conf 57.0175
# ['0.5_F', '0_D'] --> 25_BMI  lift 105.508  conf 57.5221
# ['25_BMI', '0_D'] --> 0.5_F  lift 91.0287  conf 27.4262
# ['70_B', '1_D'] --> 2.0_P  lift 58.4867  conf 26.8519
# ['70_B', '2.0_P'] --> 1_D  lift 75.2364  conf 28.7129
# ['1_D', '2.0_P'] --> 70_B  lift 92.1958  conf 34.5238
# ['70_B', '1_D'] --> 20_A  lift 51.0847  conf 27.7778
# ['70_B', '20_A'] --> 1_D  lift 66.058  conf 25.2101
# ['1_D', '20_A'] --> 70_B  lift 96.524  conf 36.1446
# ['70_B', '25_BMI', '0.0_F'] --> 1_D  lift 94.5469  conf 36.0825
# ['1_D', '25_BMI', '0.0_F'] --> 70_B  lift 118.313  conf 44.3038
# ['70_B', '1_D'] --> 25_BMI  lift 103.599  conf 56.4815
# ['70_B', '25_BMI'] --> 1_D  lift 107.999  conf 41.2162
# ['1_D', '25_BMI'] --> 70_B  lift 113.916  conf 42.6573
# ['70_B', '1_D'] --> 0.0_F  lift 81.5501  conf 53.7037
# ['70_B', '0.0_F'] --> 1_D  lift 88.8757  conf 33.9181
# ['1_D', '0.0_F'] --> 70_B  lift 109.85  conf 41.1348
# ['2.0_P', '20_A', '25_BMI', '0_D', '0.0_F'] --> 70_B  lift 97.7929  conf 36.6197
# ['2.0_P', '20_A', '25_BMI', '0_D'] --> 70_B  lift 93.0999  conf 34.8624
# ['2.0_P', '20_A', '25_BMI', '0.0_F'] --> 70_B  lift 106.135  conf 39.7436
# ['70_B', '2.0_P', '20_A'] --> 25_BMI  lift 100.882  conf 55.0
# ['2.0_P', '20_A', '25_BMI'] --> 70_B  lift 93.2555  conf 34.9206
# ['2.0_P', '20_A', '0_D', '0.0_F'] --> 70_B  lift 81.8953  conf 30.6667
# ['70_B', '2.0_P', '20_A'] --> 0_D  lift 129.374  conf 80.0
# ['70_B', '2.0_P', '0_D'] --> 20_A  lift 163.471  conf 88.8889
# ['70_B', '20_A', '0_D'] --> 2.0_P  lift 156.629  conf 71.9101
# ['2.0_P', '20_A', '0_D'] --> 70_B  lift 79.1259  conf 29.6296
# ['70_B', '2.0_P', '20_A'] --> 0.0_F  lift 104.398  conf 68.75
# ['70_B', '20_A', '0.0_F'] --> 2.0_P  lift 142.615  conf 65.4762
# ['2.0_P', '20_A', '0.0_F'] --> 70_B  lift 85.8932  conf 32.1637
# ['70_B', '2.0_P'] --> 20_A  lift 145.667  conf 79.2079
# ['70_B', '20_A'] --> 2.0_P  lift 146.429  conf 67.2269
# ['2.0_P', '20_A'] --> 70_B  lift 80.9242  conf 30.303
# ['2.0_P', '25_BMI', '0_D', '0.0_F'] --> 70_B  lift 90.1293  conf 33.75
# ['70_B', '2.0_P', '0_D'] --> 25_BMI  lift 104.448  conf 56.9444
# ['70_B', '25_BMI', '0_D'] --> 2.0_P  lift 102.647  conf 47.1264
# ['2.0_P', '25_BMI', '0_D'] --> 70_B  lift 90.488  conf 33.8843
# ['70_B', '25_BMI', '0.0_F'] --> 2.0_P  lift 76.3466  conf 35.0515
# ['2.0_P', '25_BMI', '0.0_F'] --> 70_B  lift 92.6499  conf 34.6939
# ['70_B', '2.0_P'] --> 25_BMI  lift 94.4346  conf 51.4851
# ['70_B', '25_BMI'] --> 2.0_P  lift 76.5287  conf 35.1351
# ['2.0_P', '25_BMI'] --> 70_B  lift 87.8898  conf 32.9114
# ['70_B', '2.0_P', '0_D'] --> 0.0_F  lift 107.562  conf 70.8333
# ['70_B', '0_D', '0.0_F'] --> 2.0_P  lift 98.3048  conf 45.1327
# ['2.0_P', '0_D', '0.0_F'] --> 70_B  lift 83.046  conf 31.0976
# ['70_B', '2.0_P'] --> 0_D  lift 115.283  conf 71.2871
# ['70_B', '0_D'] --> 2.0_P  lift 102.5  conf 47.0588
# ['2.0_P', '0_D'] --> 70_B  lift 81.4728  conf 30.5085
# ['70_B', '2.0_P'] --> 0.0_F  lift 100.733  conf 66.3366
# ['70_B', '0.0_F'] --> 2.0_P  lift 85.3417  conf 39.1813
# ['2.0_P', '0.0_F'] --> 70_B  lift 87.2797  conf 32.6829
# ['20_A', '25_BMI', '0_D', '0.0_F'] --> 70_B  lift 89.8258  conf 33.6364
# ['70_B', '20_A', '0_D'] --> 25_BMI  lift 105.106  conf 57.3034
# ['70_B', '25_BMI', '0_D'] --> 20_A  lift 107.806  conf 58.6207
# ['20_A', '25_BMI', '0_D'] --> 70_B  lift 87.3047  conf 32.6923
# ['70_B', '20_A', '0.0_F'] --> 25_BMI  lift 106.996  conf 58.3333
# ['70_B', '25_BMI', '0.0_F'] --> 20_A  lift 92.9005  conf 50.5155
# ['20_A', '25_BMI', '0.0_F'] --> 70_B  lift 99.1321  conf 37.1212
# ['70_B', '20_A'] --> 25_BMI  lift 104.812  conf 57.1429
# ['70_B', '25_BMI'] --> 20_A  lift 84.4969  conf 45.9459
# ['20_A', '25_BMI'] --> 70_B  lift 92.6499  conf 34.6939
# ['70_B', '20_A', '0_D'] --> 0.0_F  lift 112.609  conf 74.1573
# ['70_B', '20_A', '0.0_F'] --> 0_D  lift 127.063  conf 78.5714
# ['70_B', '0_D', '0.0_F'] --> 20_A  lift 107.414  conf 58.4071
# ['20_A', '0_D', '0.0_F'] --> 70_B  lift 81.5986  conf 30.5556
# ['70_B', '20_A'] --> 0_D  lift 120.948  conf 74.7899
# ['70_B', '0_D'] --> 20_A  lift 106.977  conf 58.1699
# ['20_A', '0_D'] --> 70_B  lift 80.2954  conf 30.0676
# ['70_B', '20_A'] --> 0.0_F  lift 107.19  conf 70.5882
# ['70_B', '0.0_F'] --> 20_A  lift 90.3393  conf 49.1228
# ['20_A', '0.0_F'] --> 70_B  lift 86.9464  conf 32.5581
# ['70_B', '25_BMI', '0_D'] --> 0.0_F  lift 108.216  conf 71.2644
# ['70_B', '25_BMI', '0.0_F'] --> 0_D  lift 103.365  conf 63.9175
# ['70_B', '0_D', '0.0_F'] --> 25_BMI  lift 100.638  conf 54.8673
# ['25_BMI', '0_D', '0.0_F'] --> 70_B  lift 96.2621  conf 36.0465
# ['70_B', '25_BMI'] --> 0_D  lift 95.0633  conf 58.7838
# ['70_B', '0_D'] --> 25_BMI  lift 104.298  conf 56.8627
# ['25_BMI', '0_D'] --> 70_B  lift 98.0309  conf 36.7089
# ['70_B', '25_BMI'] --> 0.0_F  lift 99.5245  conf 65.5405
# ['70_B', '0.0_F'] --> 25_BMI  lift 104.046  conf 56.7251
# ['25_BMI', '0.0_F'] --> 70_B  lift 103.203  conf 38.6454
# ['70_B', '0_D'] --> 0.0_F  lift 112.152  conf 73.8562
# ['70_B', '0.0_F'] --> 0_D  lift 106.866  conf 66.0819
# ['0_D', '0.0_F'] --> 70_B  lift 94.8951  conf 35.5346
# ['1_D', '2.0_P'] --> 20_A  lift 105.089  conf 57.1429
# ['1_D', '20_A'] --> 2.0_P  lift 125.964  conf 57.8313
# ['1_D', '2.0_P'] --> 25_BMI  lift 80.7926  conf 44.0476
# ['1_D', '25_BMI'] --> 2.0_P  lift 56.3571  conf 25.8741
# ['1_D', '2.0_P'] --> 0.0_F  lift 74.1182  conf 48.8095
# ['1_D', '0.0_F'] --> 2.0_P  lift 63.3355  conf 29.078
# ['1_D', '25_BMI', '0.0_F'] --> 20_A  lift 51.2141  conf 27.8481
# ['1_D', '20_A'] --> 25_BMI  lift 88.3957  conf 48.1928
# ['1_D', '25_BMI'] --> 20_A  lift 51.442  conf 27.972
# ['1_D', '20_A'] --> 0.0_F  lift 76.8407  conf 50.6024
# ['1_D', '0.0_F'] --> 20_A  lift 54.7802  conf 29.7872
# ['1_D', '25_BMI'] --> 0.0_F  lift 83.8902  conf 55.2448
# ['1_D', '0.0_F'] --> 25_BMI  lift 102.768  conf 56.0284
# ['25_BMI', '0.0_F'] --> 1_D  lift 82.4716  conf 31.4741
# ['2.0_P', '20_A', '25_BMI', '0_D'] --> 0.0_F  lift 98.9127  conf 65.1376
# ['2.0_P', '20_A', '25_BMI', '0.0_F'] --> 0_D  lift 147.204  conf 91.0256
# ['2.0_P', '20_A', '0_D', '0.0_F'] --> 25_BMI  lift 86.8193  conf 47.3333
# ['2.0_P', '25_BMI', '0_D', '0.0_F'] --> 20_A  lift 163.216  conf 88.75
# ['20_A', '25_BMI', '0_D', '0.0_F'] --> 2.0_P  lift 140.588  conf 64.5455
# ['2.0_P', '20_A', '25_BMI'] --> 0_D  lift 139.898  conf 86.5079
# ['2.0_P', '20_A', '0_D'] --> 25_BMI  lift 92.5597  conf 50.463
# ['2.0_P', '25_BMI', '0_D'] --> 20_A  lift 165.666  conf 90.0826
# ['20_A', '25_BMI', '0_D'] --> 2.0_P  lift 152.19  conf 69.8718
# ['2.0_P', '20_A', '25_BMI'] --> 0.0_F  lift 94.0035  conf 61.9048
# ['2.0_P', '20_A', '0.0_F'] --> 25_BMI  lift 83.6657  conf 45.614
# ['2.0_P', '25_BMI', '0.0_F'] --> 20_A  lift 146.373  conf 79.5918
# ['20_A', '25_BMI', '0.0_F'] --> 2.0_P  lift 128.707  conf 59.0909
# ['2.0_P', '20_A'] --> 25_BMI  lift 87.5419  conf 47.7273
# ['2.0_P', '25_BMI'] --> 20_A  lift 146.658  conf 79.7468
# ['20_A', '25_BMI'] --> 2.0_P  lift 140.022  conf 64.2857
# ['2.0_P', '20_A', '0_D'] --> 0.0_F  lift 105.453  conf 69.4444
# ['2.0_P', '20_A', '0.0_F'] --> 0_D  lift 141.857  conf 87.7193
# ['2.0_P', '0_D', '0.0_F'] --> 20_A  lift 168.206  conf 91.4634
# ['20_A', '0_D', '0.0_F'] --> 2.0_P  lift 151.259  conf 69.4444
# ['2.0_P', '20_A'] --> 0_D  lift 132.314  conf 81.8182
# ['2.0_P', '0_D'] --> 20_A  lift 168.32  conf 91.5254
# ['20_A', '0_D'] --> 2.0_P  lift 158.944  conf 72.973
# ['2.0_P', '20_A'] --> 0.0_F  lift 98.3586  conf 64.7727
# ['2.0_P', '0.0_F'] --> 20_A  lift 153.404  conf 83.4146
# ['20_A', '0.0_F'] --> 2.0_P  lift 144.364  conf 66.2791
# ['2.0_P', '25_BMI', '0_D'] --> 0.0_F  lift 100.398  conf 66.1157
# ['2.0_P', '25_BMI', '0.0_F'] --> 0_D  lift 132.014  conf 81.6327
# ['2.0_P', '0_D', '0.0_F'] --> 25_BMI  lift 89.4737  conf 48.7805
# ['25_BMI', '0_D', '0.0_F'] --> 2.0_P  lift 101.308  conf 46.5116
# ['2.0_P', '25_BMI'] --> 0_D  lift 123.847  conf 76.5823
# ['2.0_P', '0_D'] --> 25_BMI  lift 94.0421  conf 51.2712
# ['25_BMI', '0_D'] --> 2.0_P  lift 111.204  conf 51.0549
# ['2.0_P', '25_BMI'] --> 0.0_F  lift 94.1866  conf 62.0253
# ['2.0_P', '0.0_F'] --> 25_BMI  lift 87.6842  conf 47.8049
# ['25_BMI', '0.0_F'] --> 2.0_P  lift 85.0423  conf 39.0438
# ['2.0_P', '0_D'] --> 0.0_F  lift 105.524  conf 69.4915
# ['2.0_P', '0.0_F'] --> 0_D  lift 129.374  conf 80.0
# ['0_D', '0.0_F'] --> 2.0_P  lift 112.331  conf 51.5723
# ['20_A', '25_BMI', '0_D'] --> 0.0_F  lift 107.075  conf 70.5128
# ['20_A', '25_BMI', '0.0_F'] --> 0_D  lift 134.764  conf 83.3333
# ['20_A', '0_D', '0.0_F'] --> 25_BMI  lift 93.4089  conf 50.9259
# ['25_BMI', '0_D', '0.0_F'] --> 20_A  lift 117.614  conf 63.9535
# ['20_A', '25_BMI'] --> 0_D  lift 128.713  conf 79.5918
# ['20_A', '0_D'] --> 25_BMI  lift 96.6679  conf 52.7027
# ['25_BMI', '0_D'] --> 20_A  lift 121.051  conf 65.8228
# ['20_A', '25_BMI'] --> 0.0_F  lift 102.268  conf 67.3469
# ['20_A', '0.0_F'] --> 25_BMI  lift 93.8433  conf 51.1628
# ['25_BMI', '0.0_F'] --> 20_A  lift 96.715  conf 52.5896
# ['20_A', '0_D'] --> 0.0_F  lift 110.811  conf 72.973
# ['20_A', '0.0_F'] --> 0_D  lift 135.391  conf 83.7209
# ['0_D', '0.0_F'] --> 20_A  lift 124.917  conf 67.9245
# ['25_BMI', '0_D'] --> 0.0_F  lift 110.205  conf 72.5738
# ['25_BMI', '0.0_F'] --> 0_D  lift 110.818  conf 68.5259
# ['0_D', '0.0_F'] --> 25_BMI  lift 99.2089  conf 54.0881

# %%
rulse_cons_D = list()
for r in rules:
    if r['cons'].endswith('_D'):
        rulse_cons_D.append(r)

# %%
print (len(rulse_cons_D))
# Out:
# 77

# %%
sorted_rules_cons_D = sorted(rulse_cons_D, key=lambda r: r['conf'], reverse=True)

# %%
for r in sorted_rules_cons_D[:3]:
    print (r['ant'],'-->', r['cons'], ' lift', r['lift'], ' conf', r['conf'])
# Out:
# ['15_BMI', '0.0_F'] --> 0_D  lift 150.64  conf 93.1507
# ['60_B', '20_A', '0.0_F'] --> 0_D  lift 150.302  conf 92.9412
# ['2.0_P', '20_A', '25_BMI', '0.0_F'] --> 0_D  lift 147.204  conf 91.0256

# %%
df1.values[0]
# Out:
# array(['1_D', '50_A', '140_G', '70_B', '25_BMI', '0.5_F', '8.0_P'], dtype=object)

# %%
patient_test = df1.values[10]

# %%
#for r in rules:
for r in sorted_rules_cons_D[:10]:
    if (set(r['ant']) < set(patient_test))&(r['cons'].endswith('_D')):
        print (r['ant'], '-->', r['cons'])

# %%
len(sorted_rules_cons_D)
# Out:
# 77

# %%
minNumOfRulesPerLine=2
minNumOfRules2Consider=0
numberOfPatientRows=0

# %%
s =set()

# %%
for pv in df1.values:
    for i in range(1,102,100):
        mincnt=0
        for r in sorted_rules_cons_D[:i]:
            if (set(r['ant']) < set(pv))&(r['cons'].endswith('_D')):
                mincnt+=1
                if mincnt==minNumOfRulesPerLine:
                    minNumOfRules2Consider = max(minNumOfRules2Consider,i)
                    if ','.join(pv) not in s:
                        numberOfPatientRows+=1
                        s.add(','.join(pv))
                    break

# %%
len(s)
# Out:
# 551

# %%
minNumOfRules2Consider
# Out:
# 101

# %%
len(sorted_rules_cons_D)
# Out:
# 77

# %%
numberOfPatientRows
# Out:
# 551

# %%
df1.values.shape
# Out:
# (697, 7)

# %%
setOfSamples = dict()

# %%
for pv in df1.values:
    if(','.join(pv) in s):
        setOfSamples[','.join(pv)] = dict()
        for r in sorted_rules_cons_D[:102]:
            ln=len(set(r['ant']).intersection(set(pv)))
            if ln==0:
                continue
            if ln not in setOfSamples[','.join(pv)]:
                setOfSamples[','.join(pv)]=dict()
                setOfSamples[','.join(pv)][ln]=[]
            setOfSamples[','.join(pv)][ln].append(r)

# %%
setOfSamples
# Out:
# {'0_D,20_A,100_G,30_B,15_BMI,0.0_F,2.0_P': {1: [{'ant': ['70_B', '2.0_P'],
#     'conf': 28.7129,
#     'cons': '1_D',
#     'lift': 75.2364,
#     'sup': 14.4907},
#    {'ant': ['0.5_F', '20_A'],
#     'conf': 28.5714,
#     'cons': '1_D',
#     'lift': 74.8657,
#     'sup': 16.0689},
#    {'ant': ['60_B', '25_BMI', '0.0_F'],
#     'conf': 28.3784,
#     'cons': '1_D',
#     'lift': 74.3599,
#     'sup': 10.6169},
#    {'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,100_G,40_B,15_BMI,0.0_F,2.0_P': {1: [{'ant': ['70_B', '2.0_P'],
#     'conf': 28.7129,
#     'cons': '1_D',
#     'lift': 75.2364,
#     'sup': 14.4907},
#    {'ant': ['0.5_F', '20_A'],
#     'conf': 28.5714,
#     'cons': '1_D',
#     'lift': 74.8657,
#     'sup': 16.0689},
#    {'ant': ['60_B', '25_BMI', '0.0_F'],
#     'conf': 28.3784,
#     'cons': '1_D',
#     'lift': 74.3599,
#     'sup': 10.6169},
#    {'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,100_G,40_B,25_BMI,0.0_F,5.0_P': {1: [{'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,100_G,50_B,15_BMI,0.0_F,2.0_P': {1: [{'ant': ['70_B', '2.0_P'],
#     'conf': 28.7129,
#     'cons': '1_D',
#     'lift': 75.2364,
#     'sup': 14.4907},
#    {'ant': ['0.5_F', '20_A'],
#     'conf': 28.5714,
#     'cons': '1_D',
#     'lift': 74.8657,
#     'sup': 16.0689},
#    {'ant': ['60_B', '25_BMI', '0.0_F'],
#     'conf': 28.3784,
#     'cons': '1_D',
#     'lift': 74.3599,
#     'sup': 10.6169},
#    {'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,100_G,50_B,15_BMI,0.5_F,2.0_P': {1: [{'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,100_G,50_B,25_BMI,0.0_F,2.0_P': {1: [{'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,100_G,50_B,25_BMI,0.0_F,5.0_P': {1: [{'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,100_G,50_B,25_BMI,0.5_F,2.0_P': {1: [{'ant': ['60_B',
#      '25_BMI',
#      '0.0_F'],
#     'conf': 28.3784,
#     'cons': '1_D',
#     'lift': 74.3599,
#     'sup': 10.6169},
#    {'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,100_G,50_B,35_BMI,0.0_F,2.0_P': {1: [{'ant': ['70_B', '2.0_P'],
#     'conf': 28.7129,
#     'cons': '1_D',
#     'lift': 75.2364,
#     'sup': 14.4907},
#    {'ant': ['0.5_F', '20_A'],
#     'conf': 28.5714,
#     'cons': '1_D',
#     'lift': 74.8657,
#     'sup': 16.0689},
#    {'ant': ['60_B', '25_BMI', '0.0_F'],
#     'conf': 28.3784,
#     'cons': '1_D',
#     'lift': 74.3599,
#     'sup': 10.6169},
#    {'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,100_G,60_B,15_BMI,0.0_F,2.0_P': {1: [{'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,100_G,60_B,15_BMI,0.0_F,8.0_P': {1: [{'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,100_G,60_B,15_BMI,0.5_F,2.0_P': {1: [{'ant': ['60_B',
#      '25_BMI',
#      '0.0_F'],
#     'conf': 28.3784,
#     'cons': '1_D',
#     'lift': 74.3599,
#     'sup': 10.6169},
#    {'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,100_G,60_B,25_BMI,0.0_F,2.0_P': {1: [{'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,100_G,60_B,25_BMI,0.0_F,5.0_P': {1: [{'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,100_G,60_B,25_BMI,0.0_F,8.0_P': {1: [{'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,100_G,60_B,25_BMI,0.5_F,2.0_P': {1: [{'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,100_G,60_B,25_BMI,0.5_F,5.0_P': {1: [{'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,100_G,60_B,35_BMI,0.0_F,2.0_P': {1: [{'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,100_G,70_B,15_BMI,0.0_F,2.0_P': {2: [{'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,100_G,70_B,15_BMI,0.5_F,2.0_P': {2: [{'ant': ['35_BMI',
#      '2.0_P',
#      '20_A'],
#     'conf': 30.3797,
#     'cons': '1_D',
#     'lift': 79.6041,
#     'sup': 11.3343},
#    {'ant': ['70_B', '2.0_P'],
#     'conf': 28.7129,
#     'cons': '1_D',
#     'lift': 75.2364,
#     'sup': 14.4907},
#    {'ant': ['0.5_F', '20_A'],
#     'conf': 28.5714,
#     'cons': '1_D',
#     'lift': 74.8657,
#     'sup': 16.0689},
#    {'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,100_G,70_B,25_BMI,0.0_F,2.0_P': {2: [{'ant': ['60_B',
#      '25_BMI',
#      '0.0_F'],
#     'conf': 28.3784,
#     'cons': '1_D',
#     'lift': 74.3599,
#     'sup': 10.6169},
#    {'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,100_G,70_B,25_BMI,0.0_F,5.0_P': {2: [{'ant': ['60_B',
#      '25_BMI',
#      '0.0_F'],
#     'conf': 28.3784,
#     'cons': '1_D',
#     'lift': 74.3599,
#     'sup': 10.6169},
#    {'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,100_G,70_B,25_BMI,0.0_F,8.0_P': {2: [{'ant': ['60_B',
#      '25_BMI',
#      '0.0_F'],
#     'conf': 28.3784,
#     'cons': '1_D',
#     'lift': 74.3599,
#     'sup': 10.6169},
#    {'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,100_G,70_B,25_BMI,0.5_F,2.0_P': {2: [{'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,100_G,70_B,25_BMI,0.5_F,5.0_P': {2: [{'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,100_G,70_B,35_BMI,0.0_F,2.0_P': {2: [{'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,100_G,70_B,35_BMI,0.0_F,5.0_P': {2: [{'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,100_G,70_B,35_BMI,0.5_F,2.0_P': {2: [{'ant': ['70_B', '2.0_P'],
#     'conf': 28.7129,
#     'cons': '1_D',
#     'lift': 75.2364,
#     'sup': 14.4907},
#    {'ant': ['0.5_F', '20_A'],
#     'conf': 28.5714,
#     'cons': '1_D',
#     'lift': 74.8657,
#     'sup': 16.0689},
#    {'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,100_G,70_B,45_BMI,0.5_F,2.0_P': {2: [{'ant': ['35_BMI',
#      '2.0_P',
#      '20_A'],
#     'conf': 30.3797,
#     'cons': '1_D',
#     'lift': 79.6041,
#     'sup': 11.3343},
#    {'ant': ['70_B', '2.0_P'],
#     'conf': 28.7129,
#     'cons': '1_D',
#     'lift': 75.2364,
#     'sup': 14.4907},
#    {'ant': ['0.5_F', '20_A'],
#     'conf': 28.5714,
#     'cons': '1_D',
#     'lift': 74.8657,
#     'sup': 16.0689},
#    {'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,100_G,80_B,15_BMI,0.0_F,2.0_P': {1: [{'ant': ['70_B', '2.0_P'],
#     'conf': 28.7129,
#     'cons': '1_D',
#     'lift': 75.2364,
#     'sup': 14.4907},
#    {'ant': ['0.5_F', '20_A'],
#     'conf': 28.5714,
#     'cons': '1_D',
#     'lift': 74.8657,
#     'sup': 16.0689},
#    {'ant': ['60_B', '25_BMI', '0.0_F'],
#     'conf': 28.3784,
#     'cons': '1_D',
#     'lift': 74.3599,
#     'sup': 10.6169},
#    {'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,100_G,80_B,25_BMI,0.0_F,2.0_P': {1: [{'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,100_G,80_B,25_BMI,0.5_F,2.0_P': {1: [{'ant': ['60_B',
#      '25_BMI',
#      '0.0_F'],
#     'conf': 28.3784,
#     'cons': '1_D',
#     'lift': 74.3599,
#     'sup': 10.6169},
#    {'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,100_G,80_B,25_BMI,0.5_F,8.0_P': {1: [{'ant': ['60_B',
#      '25_BMI',
#      '0.0_F'],
#     'conf': 28.3784,
#     'cons': '1_D',
#     'lift': 74.3599,
#     'sup': 10.6169},
#    {'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,100_G,90_B,35_BMI,0.5_F,8.0_P': {1: [{'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,110_G,40_B,15_BMI,0.0_F,5.0_P': {1: [{'ant': ['35_BMI',
#      '2.0_P',
#      '20_A'],
#     'conf': 30.3797,
#     'cons': '1_D',
#     'lift': 79.6041,
#     'sup': 11.3343},
#    {'ant': ['0.5_F', '20_A'],
#     'conf': 28.5714,
#     'cons': '1_D',
#     'lift': 74.8657,
#     'sup': 16.0689},
#    {'ant': ['60_B', '25_BMI', '0.0_F'],
#     'conf': 28.3784,
#     'cons': '1_D',
#     'lift': 74.3599,
#     'sup': 10.6169},
#    {'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,110_G,40_B,35_BMI,0.0_F,2.0_P': {1: [{'ant': ['70_B', '2.0_P'],
#     'conf': 28.7129,
#     'cons': '1_D',
#     'lift': 75.2364,
#     'sup': 14.4907},
#    {'ant': ['0.5_F', '20_A'],
#     'conf': 28.5714,
#     'cons': '1_D',
#     'lift': 74.8657,
#     'sup': 16.0689},
#    {'ant': ['60_B', '25_BMI', '0.0_F'],
#     'conf': 28.3784,
#     'cons': '1_D',
#     'lift': 74.3599,
#     'sup': 10.6169},
#    {'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,110_G,50_B,15_BMI,0.0_F,2.0_P': {1: [{'ant': ['70_B', '2.0_P'],
#     'conf': 28.7129,
#     'cons': '1_D',
#     'lift': 75.2364,
#     'sup': 14.4907},
#    {'ant': ['0.5_F', '20_A'],
#     'conf': 28.5714,
#     'cons': '1_D',
#     'lift': 74.8657,
#     'sup': 16.0689},
#    {'ant': ['60_B', '25_BMI', '0.0_F'],
#     'conf': 28.3784,
#     'cons': '1_D',
#     'lift': 74.3599,
#     'sup': 10.6169},
#    {'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,110_G,50_B,25_BMI,0.0_F,2.0_P': {1: [{'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,110_G,50_B,25_BMI,0.0_F,5.0_P': {1: [{'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,110_G,50_B,25_BMI,0.5_F,5.0_P': {1: [{'ant': ['60_B',
#      '25_BMI',
#      '0.0_F'],
#     'conf': 28.3784,
#     'cons': '1_D',
#     'lift': 74.3599,
#     'sup': 10.6169},
#    {'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,110_G,60_B,15_BMI,0.0_F,2.0_P': {1: [{'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,110_G,60_B,15_BMI,0.0_F,5.0_P': {1: [{'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,110_G,60_B,25_BMI,0.0_F,2.0_P': {1: [{'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,110_G,60_B,25_BMI,0.0_F,5.0_P': {1: [{'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,110_G,60_B,25_BMI,0.0_F,8.0_P': {1: [{'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,110_G,60_B,25_BMI,0.5_F,2.0_P': {1: [{'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,110_G,60_B,35_BMI,0.0_F,2.0_P': {1: [{'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,110_G,60_B,35_BMI,0.0_F,5.0_P': {1: [{'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,110_G,70_B,15_BMI,0.0_F,5.0_P': {2: [{'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,110_G,70_B,25_BMI,0.0_F,2.0_P': {2: [{'ant': ['60_B',
#      '25_BMI',
#      '0.0_F'],
#     'conf': 28.3784,
#     'cons': '1_D',
#     'lift': 74.3599,
#     'sup': 10.6169},
#    {'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,110_G,70_B,25_BMI,0.0_F,5.0_P': {2: [{'ant': ['60_B',
#      '25_BMI',
#      '0.0_F'],
#     'conf': 28.3784,
#     'cons': '1_D',
#     'lift': 74.3599,
#     'sup': 10.6169},
#    {'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,110_G,70_B,25_BMI,0.0_F,8.0_P': {2: [{'ant': ['60_B',
#      '25_BMI',
#      '0.0_F'],
#     'conf': 28.3784,
#     'cons': '1_D',
#     'lift': 74.3599,
#     'sup': 10.6169},
#    {'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,110_G,70_B,25_BMI,0.5_F,2.0_P': {2: [{'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,110_G,70_B,35_BMI,0.0_F,11.0_P': {2: [{'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,110_G,70_B,35_BMI,0.0_F,2.0_P': {2: [{'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,110_G,70_B,35_BMI,0.5_F,5.0_P': {2: [{'ant': ['0.5_F', '20_A'],
#     'conf': 28.5714,
#     'cons': '1_D',
#     'lift': 74.8657,
#     'sup': 16.0689},
#    {'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,110_G,80_B,25_BMI,0.0_F,2.0_P': {1: [{'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,110_G,80_B,25_BMI,0.5_F,2.0_P': {1: [{'ant': ['60_B',
#      '25_BMI',
#      '0.0_F'],
#     'conf': 28.3784,
#     'cons': '1_D',
#     'lift': 74.3599,
#     'sup': 10.6169},
#    {'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,110_G,80_B,35_BMI,0.0_F,2.0_P': {1: [{'ant': ['70_B', '2.0_P'],
#     'conf': 28.7129,
#     'cons': '1_D',
#     'lift': 75.2364,
#     'sup': 14.4907},
#    {'ant': ['0.5_F', '20_A'],
#     'conf': 28.5714,
#     'cons': '1_D',
#     'lift': 74.8657,
#     'sup': 16.0689},
#    {'ant': ['60_B', '25_BMI', '0.0_F'],
#     'conf': 28.3784,
#     'cons': '1_D',
#     'lift': 74.3599,
#     'sup': 10.6169},
#    {'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,110_G,80_B,45_BMI,0.0_F,2.0_P': {1: [{'ant': ['70_B', '2.0_P'],
#     'conf': 28.7129,
#     'cons': '1_D',
#     'lift': 75.2364,
#     'sup': 14.4907},
#    {'ant': ['0.5_F', '20_A'],
#     'conf': 28.5714,
#     'cons': '1_D',
#     'lift': 74.8657,
#     'sup': 16.0689},
#    {'ant': ['60_B', '25_BMI', '0.0_F'],
#     'conf': 28.3784,
#     'cons': '1_D',
#     'lift': 74.3599,
#     'sup': 10.6169},
#    {'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,110_G,80_B,45_BMI,0.5_F,2.0_P': {1: [{'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,110_G,90_B,25_BMI,0.0_F,2.0_P': {1: [{'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,110_G,90_B,25_BMI,0.0_F,5.0_P': {1: [{'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,120_G,40_B,25_BMI,0.0_F,2.0_P': {1: [{'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,120_G,40_B,35_BMI,0.5_F,2.0_P': {1: [{'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,120_G,50_B,15_BMI,0.0_F,2.0_P': {1: [{'ant': ['70_B', '2.0_P'],
#     'conf': 28.7129,
#     'cons': '1_D',
#     'lift': 75.2364,
#     'sup': 14.4907},
#    {'ant': ['0.5_F', '20_A'],
#     'conf': 28.5714,
#     'cons': '1_D',
#     'lift': 74.8657,
#     'sup': 16.0689},
#    {'ant': ['60_B', '25_BMI', '0.0_F'],
#     'conf': 28.3784,
#     'cons': '1_D',
#     'lift': 74.3599,
#     'sup': 10.6169},
#    {'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,120_G,50_B,25_BMI,0.0_F,2.0_P': {1: [{'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,120_G,50_B,25_BMI,0.0_F,5.0_P': {1: [{'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,120_G,50_B,25_BMI,0.5_F,2.0_P': {1: [{'ant': ['60_B',
#      '25_BMI',
#      '0.0_F'],
#     'conf': 28.3784,
#     'cons': '1_D',
#     'lift': 74.3599,
#     'sup': 10.6169},
#    {'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,120_G,50_B,35_BMI,0.5_F,2.0_P': {1: [{'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,120_G,60_B,15_BMI,0.0_F,2.0_P': {1: [{'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,120_G,60_B,25_BMI,0.5_F,2.0_P': {1: [{'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,120_G,60_B,35_BMI,0.0_F,5.0_P': {1: [{'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,120_G,60_B,35_BMI,0.5_F,2.0_P': {1: [{'ant': ['60_B',
#      '25_BMI',
#      '0.0_F'],
#     'conf': 28.3784,
#     'cons': '1_D',
#     'lift': 74.3599,
#     'sup': 10.6169},
#    {'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,120_G,70_B,15_BMI,0.0_F,2.0_P': {2: [{'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,120_G,70_B,25_BMI,0.0_F,2.0_P': {2: [{'ant': ['60_B',
#      '25_BMI',
#      '0.0_F'],
#     'conf': 28.3784,
#     'cons': '1_D',
#     'lift': 74.3599,
#     'sup': 10.6169},
#    {'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,120_G,70_B,25_BMI,0.0_F,5.0_P': {2: [{'ant': ['60_B',
#      '25_BMI',
#      '0.0_F'],
#     'conf': 28.3784,
#     'cons': '1_D',
#     'lift': 74.3599,
#     'sup': 10.6169},
#    {'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,120_G,70_B,25_BMI,0.5_F,2.0_P': {2: [{'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,120_G,70_B,35_BMI,0.0_F,2.0_P': {2: [{'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,120_G,70_B,35_BMI,0.5_F,2.0_P': {2: [{'ant': ['70_B', '2.0_P'],
#     'conf': 28.7129,
#     'cons': '1_D',
#     'lift': 75.2364,
#     'sup': 14.4907},
#    {'ant': ['0.5_F', '20_A'],
#     'conf': 28.5714,
#     'cons': '1_D',
#     'lift': 74.8657,
#     'sup': 16.0689},
#    {'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,120_G,80_B,25_BMI,0.0_F,2.0_P': {1: [{'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,120_G,80_B,25_BMI,0.0_F,5.0_P': {1: [{'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,120_G,80_B,25_BMI,0.5_F,2.0_P': {1: [{'ant': ['60_B',
#      '25_BMI',
#      '0.0_F'],
#     'conf': 28.3784,
#     'cons': '1_D',
#     'lift': 74.3599,
#     'sup': 10.6169},
#    {'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,120_G,80_B,25_BMI,0.5_F,5.0_P': {1: [{'ant': ['60_B',
#      '25_BMI',
#      '0.0_F'],
#     'conf': 28.3784,
#     'cons': '1_D',
#     'lift': 74.3599,
#     'sup': 10.6169},
#    {'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,120_G,80_B,35_BMI,0.0_F,2.0_P': {1: [{'ant': ['70_B', '2.0_P'],
#     'conf': 28.7129,
#     'cons': '1_D',
#     'lift': 75.2364,
#     'sup': 14.4907},
#    {'ant': ['0.5_F', '20_A'],
#     'conf': 28.5714,
#     'cons': '1_D',
#     'lift': 74.8657,
#     'sup': 16.0689},
#    {'ant': ['60_B', '25_BMI', '0.0_F'],
#     'conf': 28.3784,
#     'cons': '1_D',
#     'lift': 74.3599,
#     'sup': 10.6169},
#    {'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,120_G,80_B,35_BMI,0.0_F,5.0_P': {1: [{'ant': ['0.5_F', '20_A'],
#     'conf': 28.5714,
#     'cons': '1_D',
#     'lift': 74.8657,
#     'sup': 16.0689},
#    {'ant': ['60_B', '25_BMI', '0.0_F'],
#     'conf': 28.3784,
#     'cons': '1_D',
#     'lift': 74.3599,
#     'sup': 10.6169},
#    {'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,120_G,80_B,35_BMI,0.5_F,2.0_P': {1: [{'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,120_G,80_B,35_BMI,0.5_F,5.0_P': {1: [{'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,120_G,90_B,15_BMI,0.0_F,2.0_P': {1: [{'ant': ['70_B', '2.0_P'],
#     'conf': 28.7129,
#     'cons': '1_D',
#     'lift': 75.2364,
#     'sup': 14.4907},
#    {'ant': ['0.5_F', '20_A'],
#     'conf': 28.5714,
#     'cons': '1_D',
#     'lift': 74.8657,
#     'sup': 16.0689},
#    {'ant': ['60_B', '25_BMI', '0.0_F'],
#     'conf': 28.3784,
#     'cons': '1_D',
#     'lift': 74.3599,
#     'sup': 10.6169},
#    {'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,130_G,40_B,25_BMI,0.5_F,2.0_P': {1: [{'ant': ['60_B',
#      '25_BMI',
#      '0.0_F'],
#     'conf': 28.3784,
#     'cons': '1_D',
#     'lift': 74.3599,
#     'sup': 10.6169},
#    {'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,130_G,50_B,25_BMI,0.0_F,2.0_P': {1: [{'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,130_G,60_B,15_BMI,0.0_F,2.0_P': {1: [{'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,130_G,60_B,15_BMI,0.0_F,5.0_P': {1: [{'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,130_G,60_B,25_BMI,0.0_F,5.0_P': {1: [{'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,130_G,60_B,25_BMI,0.5_F,2.0_P': {1: [{'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,130_G,60_B,35_BMI,0.5_F,2.0_P': {1: [{'ant': ['60_B',
#      '25_BMI',
#      '0.0_F'],
#     'conf': 28.3784,
#     'cons': '1_D',
#     'lift': 74.3599,
#     'sup': 10.6169},
#    {'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,130_G,70_B,25_BMI,0.0_F,2.0_P': {2: [{'ant': ['60_B',
#      '25_BMI',
#      '0.0_F'],
#     'conf': 28.3784,
#     'cons': '1_D',
#     'lift': 74.3599,
#     'sup': 10.6169},
#    {'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,130_G,70_B,35_BMI,0.0_F,2.0_P': {2: [{'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,130_G,80_B,35_BMI,0.0_F,2.0_P': {1: [{'ant': ['70_B', '2.0_P'],
#     'conf': 28.7129,
#     'cons': '1_D',
#     'lift': 75.2364,
#     'sup': 14.4907},
#    {'ant': ['0.5_F', '20_A'],
#     'conf': 28.5714,
#     'cons': '1_D',
#     'lift': 74.8657,
#     'sup': 16.0689},
#    {'ant': ['60_B', '25_BMI', '0.0_F'],
#     'conf': 28.3784,
#     'cons': '1_D',
#     'lift': 74.3599,
#     'sup': 10.6169},
#    {'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,130_G,90_B,15_BMI,0.0_F,2.0_P': {1: [{'ant': ['70_B', '2.0_P'],
#     'conf': 28.7129,
#     'cons': '1_D',
#     'lift': 75.2364,
#     'sup': 14.4907},
#    {'ant': ['0.5_F', '20_A'],
#     'conf': 28.5714,
#     'cons': '1_D',
#     'lift': 74.8657,
#     'sup': 16.0689},
#    {'ant': ['60_B', '25_BMI', '0.0_F'],
#     'conf': 28.3784,
#     'cons': '1_D',
#     'lift': 74.3599,
#     'sup': 10.6169},
#    {'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,130_G,90_B,35_BMI,0.0_F,2.0_P': {1: [{'ant': ['70_B', '2.0_P'],
#     'conf': 28.7129,
#     'cons': '1_D',
#     'lift': 75.2364,
#     'sup': 14.4907},
#    {'ant': ['0.5_F', '20_A'],
#     'conf': 28.5714,
#     'cons': '1_D',
#     'lift': 74.8657,
#     'sup': 16.0689},
#    {'ant': ['60_B', '25_BMI', '0.0_F'],
#     'conf': 28.3784,
#     'cons': '1_D',
#     'lift': 74.3599,
#     'sup': 10.6169},
#    {'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,140_G,50_B,25_BMI,0.5_F,2.0_P': {1: [{'ant': ['60_B',
#      '25_BMI',
#      '0.0_F'],
#     'conf': 28.3784,
#     'cons': '1_D',
#     'lift': 74.3599,
#     'sup': 10.6169},
#    {'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,140_G,60_B,25_BMI,0.0_F,5.0_P': {1: [{'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,140_G,70_B,15_BMI,0.5_F,2.0_P': {2: [{'ant': ['35_BMI',
#      '2.0_P',
#      '20_A'],
#     'conf': 30.3797,
#     'cons': '1_D',
#     'lift': 79.6041,
#     'sup': 11.3343},
#    {'ant': ['70_B', '2.0_P'],
#     'conf': 28.7129,
#     'cons': '1_D',
#     'lift': 75.2364,
#     'sup': 14.4907},
#    {'ant': ['0.5_F', '20_A'],
#     'conf': 28.5714,
#     'cons': '1_D',
#     'lift': 74.8657,
#     'sup': 16.0689},
#    {'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,140_G,70_B,25_BMI,0.0_F,2.0_P': {2: [{'ant': ['60_B',
#      '25_BMI',
#      '0.0_F'],
#     'conf': 28.3784,
#     'cons': '1_D',
#     'lift': 74.3599,
#     'sup': 10.6169},
#    {'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,140_G,70_B,25_BMI,0.0_F,5.0_P': {2: [{'ant': ['60_B',
#      '25_BMI',
#      '0.0_F'],
#     'conf': 28.3784,
#     'cons': '1_D',
#     'lift': 74.3599,
#     'sup': 10.6169},
#    {'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,140_G,70_B,35_BMI,0.0_F,2.0_P': {2: [{'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,140_G,80_B,15_BMI,0.5_F,2.0_P': {1: [{'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,140_G,80_B,25_BMI,0.0_F,2.0_P': {1: [{'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,140_G,80_B,25_BMI,0.0_F,5.0_P': {1: [{'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,140_G,80_B,25_BMI,0.5_F,2.0_P': {1: [{'ant': ['60_B',
#      '25_BMI',
#      '0.0_F'],
#     'conf': 28.3784,
#     'cons': '1_D',
#     'lift': 74.3599,
#     'sup': 10.6169},
#    {'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,140_G,80_B,35_BMI,0.0_F,2.0_P': {1: [{'ant': ['70_B', '2.0_P'],
#     'conf': 28.7129,
#     'cons': '1_D',
#     'lift': 75.2364,
#     'sup': 14.4907},
#    {'ant': ['0.5_F', '20_A'],
#     'conf': 28.5714,
#     'cons': '1_D',
#     'lift': 74.8657,
#     'sup': 16.0689},
#    {'ant': ['60_B', '25_BMI', '0.0_F'],
#     'conf': 28.3784,
#     'cons': '1_D',
#     'lift': 74.3599,
#     'sup': 10.6169},
#    {'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,140_G,80_B,35_BMI,0.5_F,2.0_P': {1: [{'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,150_G,60_B,25_BMI,0.0_F,2.0_P': {1: [{'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,150_G,60_B,25_BMI,0.0_F,5.0_P': {1: [{'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,150_G,60_B,35_BMI,0.5_F,8.0_P': {1: [{'ant': ['60_B',
#      '25_BMI',
#      '0.0_F'],
#     'conf': 28.3784,
#     'cons': '1_D',
#     'lift': 74.3599,
#     'sup': 10.6169},
#    {'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,150_G,70_B,25_BMI,0.0_F,2.0_P': {2: [{'ant': ['60_B',
#      '25_BMI',
#      '0.0_F'],
#     'conf': 28.3784,
#     'cons': '1_D',
#     'lift': 74.3599,
#     'sup': 10.6169},
#    {'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,150_G,70_B,45_BMI,0.5_F,8.0_P': {2: [{'ant': ['0.5_F', '20_A'],
#     'conf': 28.5714,
#     'cons': '1_D',
#     'lift': 74.8657,
#     'sup': 16.0689},
#    {'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,150_G,80_B,35_BMI,0.0_F,2.0_P': {1: [{'ant': ['70_B', '2.0_P'],
#     'conf': 28.7129,
#     'cons': '1_D',
#     'lift': 75.2364,
#     'sup': 14.4907},
#    {'ant': ['0.5_F', '20_A'],
#     'conf': 28.5714,
#     'cons': '1_D',
#     'lift': 74.8657,
#     'sup': 16.0689},
#    {'ant': ['60_B', '25_BMI', '0.0_F'],
#     'conf': 28.3784,
#     'cons': '1_D',
#     'lift': 74.3599,
#     'sup': 10.6169},
#    {'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,150_G,80_B,35_BMI,0.5_F,2.0_P': {1: [{'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,160_G,70_B,45_BMI,0.0_F,2.0_P': {2: [{'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,50_G,50_B,15_BMI,0.0_F,2.0_P': {1: [{'ant': ['70_B', '2.0_P'],
#     'conf': 28.7129,
#     'cons': '1_D',
#     'lift': 75.2364,
#     'sup': 14.4907},
#    {'ant': ['0.5_F', '20_A'],
#     'conf': 28.5714,
#     'cons': '1_D',
#     'lift': 74.8657,
#     'sup': 16.0689},
#    {'ant': ['60_B', '25_BMI', '0.0_F'],
#     'conf': 28.3784,
#     'cons': '1_D',
#     'lift': 74.3599,
#     'sup': 10.6169},
#    {'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,60_G,60_B,15_BMI,0.0_F,2.0_P': {1: [{'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,60_G,70_B,25_BMI,0.0_F,2.0_P': {2: [{'ant': ['60_B',
#      '25_BMI',
#      '0.0_F'],
#     'conf': 28.3784,
#     'cons': '1_D',
#     'lift': 74.3599,
#     'sup': 10.6169},
#    {'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,70_G,40_B,15_BMI,0.0_F,2.0_P': {1: [{'ant': ['70_B', '2.0_P'],
#     'conf': 28.7129,
#     'cons': '1_D',
#     'lift': 75.2364,
#     'sup': 14.4907},
#    {'ant': ['0.5_F', '20_A'],
#     'conf': 28.5714,
#     'cons': '1_D',
#     'lift': 74.8657,
#     'sup': 16.0689},
#    {'ant': ['60_B', '25_BMI', '0.0_F'],
#     'conf': 28.3784,
#     'cons': '1_D',
#     'lift': 74.3599,
#     'sup': 10.6169},
#    {'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,70_G,40_B,25_BMI,0.5_F,5.0_P': {1: [{'ant': ['60_B',
#      '25_BMI',
#      '0.0_F'],
#     'conf': 28.3784,
#     'cons': '1_D',
#     'lift': 74.3599,
#     'sup': 10.6169},
#    {'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,70_G,50_B,15_BMI,0.0_F,2.0_P': {1: [{'ant': ['70_B', '2.0_P'],
#     'conf': 28.7129,
#     'cons': '1_D',
#     'lift': 75.2364,
#     'sup': 14.4907},
#    {'ant': ['0.5_F', '20_A'],
#     'conf': 28.5714,
#     'cons': '1_D',
#     'lift': 74.8657,
#     'sup': 16.0689},
#    {'ant': ['60_B', '25_BMI', '0.0_F'],
#     'conf': 28.3784,
#     'cons': '1_D',
#     'lift': 74.3599,
#     'sup': 10.6169},
#    {'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,70_G,50_B,25_BMI,0.0_F,2.0_P': {1: [{'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,70_G,60_B,15_BMI,0.0_F,2.0_P': {1: [{'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,70_G,60_B,25_BMI,0.0_F,5.0_P': {1: [{'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,70_G,60_B,35_BMI,0.5_F,2.0_P': {1: [{'ant': ['60_B',
#      '25_BMI',
#      '0.0_F'],
#     'conf': 28.3784,
#     'cons': '1_D',
#     'lift': 74.3599,
#     'sup': 10.6169},
#    {'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,70_G,70_B,15_BMI,0.0_F,2.0_P': {2: [{'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,70_G,70_B,25_BMI,0.0_F,2.0_P': {2: [{'ant': ['60_B',
#      '25_BMI',
#      '0.0_F'],
#     'conf': 28.3784,
#     'cons': '1_D',
#     'lift': 74.3599,
#     'sup': 10.6169},
#    {'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,70_G,70_B,25_BMI,0.5_F,2.0_P': {2: [{'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,70_G,80_B,25_BMI,0.5_F,2.0_P': {1: [{'ant': ['60_B',
#      '25_BMI',
#      '0.0_F'],
#     'conf': 28.3784,
#     'cons': '1_D',
#     'lift': 74.3599,
#     'sup': 10.6169},
#    {'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,70_G,80_B,35_BMI,0.0_F,2.0_P': {1: [{'ant': ['70_B', '2.0_P'],
#     'conf': 28.7129,
#     'cons': '1_D',
#     'lift': 75.2364,
#     'sup': 14.4907},
#    {'ant': ['0.5_F', '20_A'],
#     'conf': 28.5714,
#     'cons': '1_D',
#     'lift': 74.8657,
#     'sup': 16.0689},
#    {'ant': ['60_B', '25_BMI', '0.0_F'],
#     'conf': 28.3784,
#     'cons': '1_D',
#     'lift': 74.3599,
#     'sup': 10.6169},
#    {'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,80_G,20_B,25_BMI,0.5_F,2.0_P': {1: [{'ant': ['60_B',
#      '25_BMI',
#      '0.0_F'],
#     'conf': 28.3784,
#     'cons': '1_D',
#     'lift': 74.3599,
#     'sup': 10.6169},
#    {'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,80_G,50_B,15_BMI,0.0_F,2.0_P': {1: [{'ant': ['70_B', '2.0_P'],
#     'conf': 28.7129,
#     'cons': '1_D',
#     'lift': 75.2364,
#     'sup': 14.4907},
#    {'ant': ['0.5_F', '20_A'],
#     'conf': 28.5714,
#     'cons': '1_D',
#     'lift': 74.8657,
#     'sup': 16.0689},
#    {'ant': ['60_B', '25_BMI', '0.0_F'],
#     'conf': 28.3784,
#     'cons': '1_D',
#     'lift': 74.3599,
#     'sup': 10.6169},
#    {'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,80_G,50_B,15_BMI,0.0_F,5.0_P': {1: [{'ant': ['35_BMI',
#      '2.0_P',
#      '20_A'],
#     'conf': 30.3797,
#     'cons': '1_D',
#     'lift': 79.6041,
#     'sup': 11.3343},
#    {'ant': ['0.5_F', '20_A'],
#     'conf': 28.5714,
#     'cons': '1_D',
#     'lift': 74.8657,
#     'sup': 16.0689},
#    {'ant': ['60_B', '25_BMI', '0.0_F'],
#     'conf': 28.3784,
#     'cons': '1_D',
#     'lift': 74.3599,
#     'sup': 10.6169},
#    {'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,80_G,50_B,25_BMI,0.0_F,2.0_P': {1: [{'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,80_G,50_B,25_BMI,0.0_F,5.0_P': {1: [{'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,80_G,50_B,25_BMI,0.5_F,2.0_P': {1: [{'ant': ['60_B',
#      '25_BMI',
#      '0.0_F'],
#     'conf': 28.3784,
#     'cons': '1_D',
#     'lift': 74.3599,
#     'sup': 10.6169},
#    {'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,80_G,60_B,15_BMI,0.0_F,2.0_P': {1: [{'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,80_G,60_B,15_BMI,0.0_F,5.0_P': {1: [{'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,80_G,60_B,15_BMI,0.5_F,2.0_P': {1: [{'ant': ['60_B',
#      '25_BMI',
#      '0.0_F'],
#     'conf': 28.3784,
#     'cons': '1_D',
#     'lift': 74.3599,
#     'sup': 10.6169},
#    {'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,80_G,60_B,25_BMI,0.0_F,2.0_P': {1: [{'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,80_G,60_B,25_BMI,0.0_F,5.0_P': {1: [{'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,80_G,60_B,25_BMI,0.5_F,5.0_P': {1: [{'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,80_G,60_B,35_BMI,0.0_F,2.0_P': {1: [{'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,80_G,60_B,35_BMI,0.5_F,2.0_P': {1: [{'ant': ['60_B',
#      '25_BMI',
#      '0.0_F'],
#     'conf': 28.3784,
#     'cons': '1_D',
#     'lift': 74.3599,
#     'sup': 10.6169},
#    {'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,80_G,70_B,15_BMI,0.0_F,5.0_P': {2: [{'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,80_G,70_B,25_BMI,0.0_F,2.0_P': {2: [{'ant': ['60_B',
#      '25_BMI',
#      '0.0_F'],
#     'conf': 28.3784,
#     'cons': '1_D',
#     'lift': 74.3599,
#     'sup': 10.6169},
#    {'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,80_G,70_B,25_BMI,0.0_F,5.0_P': {2: [{'ant': ['60_B',
#      '25_BMI',
#      '0.0_F'],
#     'conf': 28.3784,
#     'cons': '1_D',
#     'lift': 74.3599,
#     'sup': 10.6169},
#    {'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,80_G,70_B,25_BMI,0.5_F,2.0_P': {2: [{'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,80_G,70_B,35_BMI,0.0_F,5.0_P': {2: [{'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,80_G,80_B,25_BMI,0.0_F,5.0_P': {1: [{'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,80_G,80_B,35_BMI,0.0_F,2.0_P': {1: [{'ant': ['70_B', '2.0_P'],
#     'conf': 28.7129,
#     'cons': '1_D',
#     'lift': 75.2364,
#     'sup': 14.4907},
#    {'ant': ['0.5_F', '20_A'],
#     'conf': 28.5714,
#     'cons': '1_D',
#     'lift': 74.8657,
#     'sup': 16.0689},
#    {'ant': ['60_B', '25_BMI', '0.0_F'],
#     'conf': 28.3784,
#     'cons': '1_D',
#     'lift': 74.3599,
#     'sup': 10.6169},
#    {'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,80_G,80_B,35_BMI,0.0_F,8.0_P': {1: [{'ant': ['0.5_F', '20_A'],
#     'conf': 28.5714,
#     'cons': '1_D',
#     'lift': 74.8657,
#     'sup': 16.0689},
#    {'ant': ['60_B', '25_BMI', '0.0_F'],
#     'conf': 28.3784,
#     'cons': '1_D',
#     'lift': 74.3599,
#     'sup': 10.6169},
#    {'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,80_G,90_B,35_BMI,0.0_F,5.0_P': {1: [{'ant': ['0.5_F', '20_A'],
#     'conf': 28.5714,
#     'cons': '1_D',
#     'lift': 74.8657,
#     'sup': 16.0689},
#    {'ant': ['60_B', '25_BMI', '0.0_F'],
#     'conf': 28.3784,
#     'cons': '1_D',
#     'lift': 74.3599,
#     'sup': 10.6169},
#    {'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,90_G,50_B,15_BMI,0.0_F,2.0_P': {1: [{'ant': ['70_B', '2.0_P'],
#     'conf': 28.7129,
#     'cons': '1_D',
#     'lift': 75.2364,
#     'sup': 14.4907},
#    {'ant': ['0.5_F', '20_A'],
#     'conf': 28.5714,
#     'cons': '1_D',
#     'lift': 74.8657,
#     'sup': 16.0689},
#    {'ant': ['60_B', '25_BMI', '0.0_F'],
#     'conf': 28.3784,
#     'cons': '1_D',
#     'lift': 74.3599,
#     'sup': 10.6169},
#    {'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,90_G,50_B,15_BMI,0.0_F,5.0_P': {1: [{'ant': ['35_BMI',
#      '2.0_P',
#      '20_A'],
#     'conf': 30.3797,
#     'cons': '1_D',
#     'lift': 79.6041,
#     'sup': 11.3343},
#    {'ant': ['0.5_F', '20_A'],
#     'conf': 28.5714,
#     'cons': '1_D',
#     'lift': 74.8657,
#     'sup': 16.0689},
#    {'ant': ['60_B', '25_BMI', '0.0_F'],
#     'conf': 28.3784,
#     'cons': '1_D',
#     'lift': 74.3599,
#     'sup': 10.6169},
#    {'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,90_G,50_B,15_BMI,0.5_F,2.0_P': {1: [{'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,90_G,50_B,25_BMI,0.0_F,2.0_P': {1: [{'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,90_G,50_B,25_BMI,0.0_F,5.0_P': {1: [{'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,90_G,50_B,25_BMI,0.0_F,8.0_P': {1: [{'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,90_G,50_B,25_BMI,0.5_F,2.0_P': {1: [{'ant': ['60_B',
#      '25_BMI',
#      '0.0_F'],
#     'conf': 28.3784,
#     'cons': '1_D',
#     'lift': 74.3599,
#     'sup': 10.6169},
#    {'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,90_G,60_B,15_BMI,0.0_F,2.0_P': {1: [{'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,90_G,60_B,15_BMI,0.0_F,5.0_P': {1: [{'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,90_G,60_B,15_BMI,0.5_F,2.0_P': {1: [{'ant': ['60_B',
#      '25_BMI',
#      '0.0_F'],
#     'conf': 28.3784,
#     'cons': '1_D',
#     'lift': 74.3599,
#     'sup': 10.6169},
#    {'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,90_G,60_B,25_BMI,0.0_F,2.0_P': {1: [{'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,90_G,60_B,25_BMI,0.0_F,5.0_P': {1: [{'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,90_G,60_B,25_BMI,0.5_F,2.0_P': {1: [{'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,90_G,60_B,35_BMI,0.0_F,2.0_P': {1: [{'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,90_G,60_B,35_BMI,0.0_F,5.0_P': {1: [{'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,90_G,60_B,35_BMI,0.5_F,2.0_P': {1: [{'ant': ['60_B',
#      '25_BMI',
#      '0.0_F'],
#     'conf': 28.3784,
#     'cons': '1_D',
#     'lift': 74.3599,
#     'sup': 10.6169},
#    {'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,90_G,70_B,15_BMI,0.0_F,2.0_P': {2: [{'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,90_G,70_B,15_BMI,0.0_F,5.0_P': {2: [{'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,90_G,70_B,15_BMI,0.0_F,8.0_P': {2: [{'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,90_G,70_B,25_BMI,0.0_F,2.0_P': {2: [{'ant': ['60_B',
#      '25_BMI',
#      '0.0_F'],
#     'conf': 28.3784,
#     'cons': '1_D',
#     'lift': 74.3599,
#     'sup': 10.6169},
#    {'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,90_G,70_B,25_BMI,0.0_F,5.0_P': {2: [{'ant': ['60_B',
#      '25_BMI',
#      '0.0_F'],
#     'conf': 28.3784,
#     'cons': '1_D',
#     'lift': 74.3599,
#     'sup': 10.6169},
#    {'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,90_G,70_B,25_BMI,0.5_F,2.0_P': {2: [{'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,90_G,70_B,25_BMI,0.5_F,5.0_P': {2: [{'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,90_G,70_B,35_BMI,0.0_F,2.0_P': {2: [{'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,90_G,70_B,35_BMI,0.0_F,5.0_P': {2: [{'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,90_G,70_B,35_BMI,0.5_F,5.0_P': {2: [{'ant': ['0.5_F', '20_A'],
#     'conf': 28.5714,
#     'cons': '1_D',
#     'lift': 74.8657,
#     'sup': 16.0689},
#    {'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,90_G,80_B,15_BMI,0.0_F,2.0_P': {1: [{'ant': ['70_B', '2.0_P'],
#     'conf': 28.7129,
#     'cons': '1_D',
#     'lift': 75.2364,
#     'sup': 14.4907},
#    {'ant': ['0.5_F', '20_A'],
#     'conf': 28.5714,
#     'cons': '1_D',
#     'lift': 74.8657,
#     'sup': 16.0689},
#    {'ant': ['60_B', '25_BMI', '0.0_F'],
#     'conf': 28.3784,
#     'cons': '1_D',
#     'lift': 74.3599,
#     'sup': 10.6169},
#    {'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,90_G,80_B,25_BMI,0.0_F,2.0_P': {1: [{'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,90_G,80_B,25_BMI,0.5_F,2.0_P': {1: [{'ant': ['60_B',
#      '25_BMI',
#      '0.0_F'],
#     'conf': 28.3784,
#     'cons': '1_D',
#     'lift': 74.3599,
#     'sup': 10.6169},
#    {'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '0_D,20_A,90_G,80_B,35_BMI,0.0_F,2.0_P': {1: [{'ant': ['70_B', '2.0_P'],
#     'conf': 28.7129,
#     'cons': '1_D',
#     'lift': 75.2364,
#     'sup': 14.4907},
#    {'ant': ['0.5_F', '20_A'],
#     'conf': 28.5714,
#     'cons': '1_D',
#     'lift': 74.8657,
#     'sup': 16.0689},
#    {'ant': ['60_B', '25_BMI', '0.0_F'],
#     'conf': 28.3784,
#     'cons': '1_D',
#     'lift': 74.3599,
#     'sup': 10.6169},
#    {'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
# ...
#     'sup': 13.9168},
#    {'ant': ['70_B', '0.0_F'],
#     'conf': 33.9181,
#     'cons': '1_D',
#     'lift': 88.8757,
#     'sup': 24.5337},
#    {'ant': ['35_BMI', '20_A'],
#     'conf': 31.4286,
#     'cons': '1_D',
#     'lift': 82.3523,
#     'sup': 15.0646},
#    {'ant': ['0.5_F', '2.0_P'],
#     'conf': 31.4286,
#     'cons': '1_D',
#     'lift': 82.3523,
#     'sup': 15.0646},
#    {'ant': ['35_BMI', '2.0_P', '20_A'],
#     'conf': 30.3797,
#     'cons': '1_D',
#     'lift': 79.6041,
#     'sup': 11.3343},
#    {'ant': ['70_B', '2.0_P'],
#     'conf': 28.7129,
#     'cons': '1_D',
#     'lift': 75.2364,
#     'sup': 14.4907},
#    {'ant': ['0.5_F', '20_A'],
#     'conf': 28.5714,
#     'cons': '1_D',
#     'lift': 74.8657,
#     'sup': 16.0689},
#    {'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '1_D,50_A,150_G,80_B,15_BMI,0.0_F,11.0_P': {1: [{'ant': ['35_BMI', '0.0_F'],
#     'conf': 37.931,
#     'cons': '1_D',
#     'lift': 99.3907,
#     'sup': 16.6428},
#    {'ant': ['70_B', '25_BMI', '0.0_F'],
#     'conf': 36.0825,
#     'cons': '1_D',
#     'lift': 94.5469,
#     'sup': 13.9168},
#    {'ant': ['70_B', '0.0_F'],
#     'conf': 33.9181,
#     'cons': '1_D',
#     'lift': 88.8757,
#     'sup': 24.5337},
#    {'ant': ['25_BMI', '0.0_F'],
#     'conf': 31.4741,
#     'cons': '1_D',
#     'lift': 82.4716,
#     'sup': 36.0115},
#    {'ant': ['5.0_P', '25_BMI', '0.0_F'],
#     'conf': 31.3253,
#     'cons': '1_D',
#     'lift': 82.0817,
#     'sup': 11.9082},
#    {'ant': ['5.0_P', '0.0_F'],
#     'conf': 31.1594,
#     'cons': '1_D',
#     'lift': 81.6471,
#     'sup': 19.7991},
#    {'ant': ['60_B', '25_BMI', '0.0_F'],
#     'conf': 28.3784,
#     'cons': '1_D',
#     'lift': 74.3599,
#     'sup': 10.6169}]},
#  '1_D,50_A,160_G,100_B,35_BMI,0.0_F,5.0_P': {1: [{'ant': ['35_BMI',
#      '2.0_P',
#      '20_A'],
#     'conf': 30.3797,
#     'cons': '1_D',
#     'lift': 79.6041,
#     'sup': 11.3343},
#    {'ant': ['60_B', '25_BMI', '0.0_F'],
#     'conf': 28.3784,
#     'cons': '1_D',
#     'lift': 74.3599,
#     'sup': 10.6169}]},
#  '1_D,50_A,160_G,60_B,15_BMI,0.0_F,8.0_P': {2: [{'ant': ['60_B',
#      '25_BMI',
#      '0.0_F'],
#     'conf': 28.3784,
#     'cons': '1_D',
#     'lift': 74.3599,
#     'sup': 10.6169}]},
#  '1_D,50_A,160_G,70_B,25_BMI,0.5_F,5.0_P': {1: [{'ant': ['5.0_P', '20_A'],
#     'conf': 31.25,
#     'cons': '1_D',
#     'lift': 81.8844,
#     'sup': 13.7733},
#    {'ant': ['5.0_P', '0.0_F'],
#     'conf': 31.1594,
#     'cons': '1_D',
#     'lift': 81.6471,
#     'sup': 19.7991},
#    {'ant': ['70_B', '2.0_P'],
#     'conf': 28.7129,
#     'cons': '1_D',
#     'lift': 75.2364,
#     'sup': 14.4907},
#    {'ant': ['0.5_F', '20_A'],
#     'conf': 28.5714,
#     'cons': '1_D',
#     'lift': 74.8657,
#     'sup': 16.0689},
#    {'ant': ['60_B', '25_BMI', '0.0_F'],
#     'conf': 28.3784,
#     'cons': '1_D',
#     'lift': 74.3599,
#     'sup': 10.6169},
#    {'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '1_D,50_A,160_G,80_B,35_BMI,0.5_F,2.0_P': {1: [{'ant': ['70_B', '2.0_P'],
#     'conf': 28.7129,
#     'cons': '1_D',
#     'lift': 75.2364,
#     'sup': 14.4907},
#    {'ant': ['0.5_F', '20_A'],
#     'conf': 28.5714,
#     'cons': '1_D',
#     'lift': 74.8657,
#     'sup': 16.0689}]},
#  '1_D,50_A,170_G,80_B,25_BMI,1.0_F,5.0_P': {1: [{'ant': ['5.0_P', '20_A'],
#     'conf': 31.25,
#     'cons': '1_D',
#     'lift': 81.8844,
#     'sup': 13.7733},
#    {'ant': ['5.0_P', '0.0_F'],
#     'conf': 31.1594,
#     'cons': '1_D',
#     'lift': 81.6471,
#     'sup': 19.7991},
#    {'ant': ['60_B', '25_BMI', '0.0_F'],
#     'conf': 28.3784,
#     'cons': '1_D',
#     'lift': 74.3599,
#     'sup': 10.6169}]},
#  '1_D,50_A,170_G,90_B,25_BMI,0.0_F,8.0_P': {2: [{'ant': ['60_B',
#      '25_BMI',
#      '0.0_F'],
#     'conf': 28.3784,
#     'cons': '1_D',
#     'lift': 74.3599,
#     'sup': 10.6169}]},
#  '1_D,50_A,180_G,60_B,25_BMI,0.0_F,2.0_P': {3: [{'ant': ['60_B',
#      '25_BMI',
#      '0.0_F'],
#     'conf': 28.3784,
#     'cons': '1_D',
#     'lift': 74.3599,
#     'sup': 10.6169}]},
#  '1_D,50_A,180_G,70_B,35_BMI,1.0_F,5.0_P': {1: [{'ant': ['70_B', '25_BMI'],
#     'conf': 41.2162,
#     'cons': '1_D',
#     'lift': 107.999,
#     'sup': 21.2339},
#    {'ant': ['5.0_P', '25_BMI'],
#     'conf': 38.0531,
#     'cons': '1_D',
#     'lift': 99.7106,
#     'sup': 16.2123},
#    {'ant': ['35_BMI', '0.0_F'],
#     'conf': 37.931,
#     'cons': '1_D',
#     'lift': 99.3907,
#     'sup': 16.6428},
#    {'ant': ['35_BMI', '2.0_P'],
#     'conf': 37.5,
#     'cons': '1_D',
#     'lift': 98.2613,
#     'sup': 13.7733},
#    {'ant': ['70_B', '25_BMI', '0.0_F'],
#     'conf': 36.0825,
#     'cons': '1_D',
#     'lift': 94.5469,
#     'sup': 13.9168},
#    {'ant': ['70_B', '0.0_F'],
#     'conf': 33.9181,
#     'cons': '1_D',
#     'lift': 88.8757,
#     'sup': 24.5337},
#    {'ant': ['35_BMI', '20_A'],
#     'conf': 31.4286,
#     'cons': '1_D',
#     'lift': 82.3523,
#     'sup': 15.0646},
#    {'ant': ['5.0_P', '25_BMI', '0.0_F'],
#     'conf': 31.3253,
#     'cons': '1_D',
#     'lift': 82.0817,
#     'sup': 11.9082},
#    {'ant': ['5.0_P', '20_A'],
#     'conf': 31.25,
#     'cons': '1_D',
#     'lift': 81.8844,
#     'sup': 13.7733},
#    {'ant': ['5.0_P', '0.0_F'],
#     'conf': 31.1594,
#     'cons': '1_D',
#     'lift': 81.6471,
#     'sup': 19.7991},
#    {'ant': ['35_BMI', '2.0_P', '20_A'],
#     'conf': 30.3797,
#     'cons': '1_D',
#     'lift': 79.6041,
#     'sup': 11.3343},
#    {'ant': ['70_B', '2.0_P'],
#     'conf': 28.7129,
#     'cons': '1_D',
#     'lift': 75.2364,
#     'sup': 14.4907},
#    {'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '1_D,50_A,190_G,70_B,15_BMI,0.0_F,8.0_P': {1: [{'ant': ['25_BMI', '0.0_F'],
#     'conf': 31.4741,
#     'cons': '1_D',
#     'lift': 82.4716,
#     'sup': 36.0115},
#    {'ant': ['5.0_P', '25_BMI', '0.0_F'],
#     'conf': 31.3253,
#     'cons': '1_D',
#     'lift': 82.0817,
#     'sup': 11.9082},
#    {'ant': ['5.0_P', '0.0_F'],
#     'conf': 31.1594,
#     'cons': '1_D',
#     'lift': 81.6471,
#     'sup': 19.7991},
#    {'ant': ['70_B', '2.0_P'],
#     'conf': 28.7129,
#     'cons': '1_D',
#     'lift': 75.2364,
#     'sup': 14.4907},
#    {'ant': ['60_B', '25_BMI', '0.0_F'],
#     'conf': 28.3784,
#     'cons': '1_D',
#     'lift': 74.3599,
#     'sup': 10.6169},
#    {'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '1_D,50_A,190_G,70_B,25_BMI,0.0_F,2.0_P': {1: [{'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '1_D,50_A,190_G,70_B,25_BMI,0.0_F,8.0_P': {1: [{'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '1_D,50_A,190_G,70_B,35_BMI,0.5_F,8.0_P': {1: [{'ant': ['30_A', '70_B'],
#     'conf': 48.6111,
#     'cons': '0_D',
#     'lift': 78.6124,
#     'sup': 10.33},
#    {'ant': ['8.0_P', '0.0_F'],
#     'conf': 47.4359,
#     'cons': '1_D',
#     'lift': 124.296,
#     'sup': 11.1908},
#    {'ant': ['5.0_P', '70_B'],
#     'conf': 44.1558,
#     'cons': '1_D',
#     'lift': 115.702,
#     'sup': 11.0473},
#    {'ant': ['0.5_F', '25_BMI'],
#     'conf': 42.9825,
#     'cons': '1_D',
#     'lift': 112.627,
#     'sup': 16.3558},
#    {'ant': ['70_B', '25_BMI'],
#     'conf': 41.2162,
#     'cons': '1_D',
#     'lift': 107.999,
#     'sup': 21.2339},
#    {'ant': ['35_BMI', '0.0_F'],
#     'conf': 37.931,
#     'cons': '1_D',
#     'lift': 99.3907,
#     'sup': 16.6428},
#    {'ant': ['35_BMI', '2.0_P'],
#     'conf': 37.5,
#     'cons': '1_D',
#     'lift': 98.2613,
#     'sup': 13.7733},
#    {'ant': ['70_B', '25_BMI', '0.0_F'],
#     'conf': 36.0825,
#     'cons': '1_D',
#     'lift': 94.5469,
#     'sup': 13.9168},
#    {'ant': ['70_B', '0.0_F'],
#     'conf': 33.9181,
#     'cons': '1_D',
#     'lift': 88.8757,
#     'sup': 24.5337},
#    {'ant': ['35_BMI', '20_A'],
#     'conf': 31.4286,
#     'cons': '1_D',
#     'lift': 82.3523,
#     'sup': 15.0646},
#    {'ant': ['0.5_F', '2.0_P'],
#     'conf': 31.4286,
#     'cons': '1_D',
#     'lift': 82.3523,
#     'sup': 15.0646},
#    {'ant': ['35_BMI', '2.0_P', '20_A'],
#     'conf': 30.3797,
#     'cons': '1_D',
#     'lift': 79.6041,
#     'sup': 11.3343},
#    {'ant': ['70_B', '2.0_P'],
#     'conf': 28.7129,
#     'cons': '1_D',
#     'lift': 75.2364,
#     'sup': 14.4907},
#    {'ant': ['0.5_F', '20_A'],
#     'conf': 28.5714,
#     'cons': '1_D',
#     'lift': 74.8657,
#     'sup': 16.0689},
#    {'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '1_D,50_A,90_G,70_B,35_BMI,0.0_F,5.0_P': {1: [{'ant': ['35_BMI',
#      '2.0_P',
#      '20_A'],
#     'conf': 30.3797,
#     'cons': '1_D',
#     'lift': 79.6041,
#     'sup': 11.3343},
#    {'ant': ['70_B', '2.0_P'],
#     'conf': 28.7129,
#     'cons': '1_D',
#     'lift': 75.2364,
#     'sup': 14.4907},
#    {'ant': ['60_B', '25_BMI', '0.0_F'],
#     'conf': 28.3784,
#     'cons': '1_D',
#     'lift': 74.3599,
#     'sup': 10.6169},
#    {'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '1_D,50_A,90_G,80_B,25_BMI,0.5_F,11.0_P': {1: [{'ant': ['70_B', '25_BMI'],
#     'conf': 41.2162,
#     'cons': '1_D',
#     'lift': 107.999,
#     'sup': 21.2339},
#    {'ant': ['80_B', '0.0_F'],
#     'conf': 38.3562,
#     'cons': '1_D',
#     'lift': 100.505,
#     'sup': 10.4735},
#    {'ant': ['5.0_P', '25_BMI'],
#     'conf': 38.0531,
#     'cons': '1_D',
#     'lift': 99.7106,
#     'sup': 16.2123},
#    {'ant': ['70_B', '25_BMI', '0.0_F'],
#     'conf': 36.0825,
#     'cons': '1_D',
#     'lift': 94.5469,
#     'sup': 13.9168},
#    {'ant': ['60_B', '25_BMI'],
#     'conf': 32.381,
#     'cons': '1_D',
#     'lift': 84.8478,
#     'sup': 15.0646},
#    {'ant': ['25_BMI', '0.0_F'],
#     'conf': 31.4741,
#     'cons': '1_D',
#     'lift': 82.4716,
#     'sup': 36.0115},
#    {'ant': ['0.5_F', '2.0_P'],
#     'conf': 31.4286,
#     'cons': '1_D',
#     'lift': 82.3523,
#     'sup': 15.0646},
#    {'ant': ['5.0_P', '25_BMI', '0.0_F'],
#     'conf': 31.3253,
#     'cons': '1_D',
#     'lift': 82.0817,
#     'sup': 11.9082},
#    {'ant': ['0.5_F', '20_A'],
#     'conf': 28.5714,
#     'cons': '1_D',
#     'lift': 74.8657,
#     'sup': 16.0689},
#    {'ant': ['60_B', '25_BMI', '0.0_F'],
#     'conf': 28.3784,
#     'cons': '1_D',
#     'lift': 74.3599,
#     'sup': 10.6169}]},
#  '1_D,60_A,100_G,80_B,25_BMI,0.5_F,2.0_P': {1: [{'ant': ['5.0_P',
#      '25_BMI',
#      '0.0_F'],
#     'conf': 31.3253,
#     'cons': '1_D',
#     'lift': 82.0817,
#     'sup': 11.9082},
#    {'ant': ['35_BMI', '2.0_P', '20_A'],
#     'conf': 30.3797,
#     'cons': '1_D',
#     'lift': 79.6041,
#     'sup': 11.3343},
#    {'ant': ['70_B', '2.0_P'],
#     'conf': 28.7129,
#     'cons': '1_D',
#     'lift': 75.2364,
#     'sup': 14.4907},
#    {'ant': ['0.5_F', '20_A'],
#     'conf': 28.5714,
#     'cons': '1_D',
#     'lift': 74.8657,
#     'sup': 16.0689},
#    {'ant': ['60_B', '25_BMI', '0.0_F'],
#     'conf': 28.3784,
#     'cons': '1_D',
#     'lift': 74.3599,
#     'sup': 10.6169}]},
#  '1_D,60_A,130_G,70_B,15_BMI,0.0_F,5.0_P': {1: [{'ant': ['70_B', '2.0_P'],
#     'conf': 28.7129,
#     'cons': '1_D',
#     'lift': 75.2364,
#     'sup': 14.4907},
#    {'ant': ['60_B', '25_BMI', '0.0_F'],
#     'conf': 28.3784,
#     'cons': '1_D',
#     'lift': 74.3599,
#     'sup': 10.6169},
#    {'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '1_D,60_A,140_G,70_B,35_BMI,0.5_F,5.0_P': {1: [{'ant': ['0.5_F', '25_BMI'],
#     'conf': 42.9825,
#     'cons': '1_D',
#     'lift': 112.627,
#     'sup': 16.3558},
#    {'ant': ['70_B', '25_BMI'],
#     'conf': 41.2162,
#     'cons': '1_D',
#     'lift': 107.999,
#     'sup': 21.2339},
#    {'ant': ['5.0_P', '25_BMI'],
#     'conf': 38.0531,
#     'cons': '1_D',
#     'lift': 99.7106,
#     'sup': 16.2123},
#    {'ant': ['35_BMI', '0.0_F'],
#     'conf': 37.931,
#     'cons': '1_D',
#     'lift': 99.3907,
#     'sup': 16.6428},
#    {'ant': ['35_BMI', '2.0_P'],
#     'conf': 37.5,
#     'cons': '1_D',
#     'lift': 98.2613,
#     'sup': 13.7733},
#    {'ant': ['70_B', '25_BMI', '0.0_F'],
#     'conf': 36.0825,
#     'cons': '1_D',
#     'lift': 94.5469,
#     'sup': 13.9168},
#    {'ant': ['70_B', '0.0_F'],
#     'conf': 33.9181,
#     'cons': '1_D',
#     'lift': 88.8757,
#     'sup': 24.5337},
#    {'ant': ['35_BMI', '20_A'],
#     'conf': 31.4286,
#     'cons': '1_D',
#     'lift': 82.3523,
#     'sup': 15.0646},
#    {'ant': ['0.5_F', '2.0_P'],
#     'conf': 31.4286,
#     'cons': '1_D',
#     'lift': 82.3523,
#     'sup': 15.0646},
#    {'ant': ['5.0_P', '25_BMI', '0.0_F'],
#     'conf': 31.3253,
#     'cons': '1_D',
#     'lift': 82.0817,
#     'sup': 11.9082},
#    {'ant': ['5.0_P', '20_A'],
#     'conf': 31.25,
#     'cons': '1_D',
#     'lift': 81.8844,
#     'sup': 13.7733},
#    {'ant': ['5.0_P', '0.0_F'],
#     'conf': 31.1594,
#     'cons': '1_D',
#     'lift': 81.6471,
#     'sup': 19.7991},
#    {'ant': ['35_BMI', '2.0_P', '20_A'],
#     'conf': 30.3797,
#     'cons': '1_D',
#     'lift': 79.6041,
#     'sup': 11.3343},
#    {'ant': ['70_B', '2.0_P'],
#     'conf': 28.7129,
#     'cons': '1_D',
#     'lift': 75.2364,
#     'sup': 14.4907},
#    {'ant': ['0.5_F', '20_A'],
#     'conf': 28.5714,
#     'cons': '1_D',
#     'lift': 74.8657,
#     'sup': 16.0689},
#    {'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '1_D,60_A,140_G,90_B,25_BMI,0.5_F,5.0_P': {1: [{'ant': ['5.0_P', '20_A'],
#     'conf': 31.25,
#     'cons': '1_D',
#     'lift': 81.8844,
#     'sup': 13.7733},
#    {'ant': ['5.0_P', '0.0_F'],
#     'conf': 31.1594,
#     'cons': '1_D',
#     'lift': 81.6471,
#     'sup': 19.7991},
#    {'ant': ['0.5_F', '20_A'],
#     'conf': 28.5714,
#     'cons': '1_D',
#     'lift': 74.8657,
#     'sup': 16.0689},
#    {'ant': ['60_B', '25_BMI', '0.0_F'],
#     'conf': 28.3784,
#     'cons': '1_D',
#     'lift': 74.3599,
#     'sup': 10.6169}]},
#  '1_D,60_A,150_G,90_B,25_BMI,0.5_F,2.0_P': {1: [{'ant': ['5.0_P',
#      '25_BMI',
#      '0.0_F'],
#     'conf': 31.3253,
#     'cons': '1_D',
#     'lift': 82.0817,
#     'sup': 11.9082},
#    {'ant': ['35_BMI', '2.0_P', '20_A'],
#     'conf': 30.3797,
#     'cons': '1_D',
#     'lift': 79.6041,
#     'sup': 11.3343},
#    {'ant': ['70_B', '2.0_P'],
#     'conf': 28.7129,
#     'cons': '1_D',
#     'lift': 75.2364,
#     'sup': 14.4907},
#    {'ant': ['0.5_F', '20_A'],
#     'conf': 28.5714,
#     'cons': '1_D',
#     'lift': 74.8657,
#     'sup': 16.0689},
#    {'ant': ['60_B', '25_BMI', '0.0_F'],
#     'conf': 28.3784,
#     'cons': '1_D',
#     'lift': 74.3599,
#     'sup': 10.6169}]},
#  '1_D,60_A,180_G,60_B,25_BMI,0.5_F,8.0_P': {2: [{'ant': ['60_B',
#      '25_BMI',
#      '0.0_F'],
#     'conf': 28.3784,
#     'cons': '1_D',
#     'lift': 74.3599,
#     'sup': 10.6169}]},
#  '1_D,60_A,190_G,70_B,25_BMI,0.5_F,2.0_P': {1: [{'ant': ['0.5_F', '20_A'],
#     'conf': 28.5714,
#     'cons': '1_D',
#     'lift': 74.8657,
#     'sup': 16.0689},
#    {'ant': ['60_B', '25_BMI', '0.0_F'],
#     'conf': 28.3784,
#     'cons': '1_D',
#     'lift': 74.3599,
#     'sup': 10.6169},
#    {'ant': ['70_B', '20_A'],
#     'conf': 25.2101,
#     'cons': '1_D',
#     'lift': 66.058,
#     'sup': 17.0732}]},
#  '1_D,60_A,190_G,90_B,35_BMI,0.0_F,8.0_P': {1: [{'ant': ['35_BMI', '2.0_P'],
#     'conf': 37.5,
#     'cons': '1_D',
#     'lift': 98.2613,
#     'sup': 13.7733},
#    {'ant': ['70_B', '25_BMI', '0.0_F'],
#     'conf': 36.0825,
#     'cons': '1_D',
#     'lift': 94.5469,
#     'sup': 13.9168},
#    {'ant': ['70_B', '0.0_F'],
#     'conf': 33.9181,
#     'cons': '1_D',
#     'lift': 88.8757,
#     'sup': 24.5337},
#    {'ant': ['25_BMI', '0.0_F'],
#     'conf': 31.4741,
#     'cons': '1_D',
#     'lift': 82.4716,
#     'sup': 36.0115},
#    {'ant': ['35_BMI', '20_A'],
#     'conf': 31.4286,
#     'cons': '1_D',
#     'lift': 82.3523,
#     'sup': 15.0646},
#    {'ant': ['5.0_P', '25_BMI', '0.0_F'],
#     'conf': 31.3253,
#     'cons': '1_D',
#     'lift': 82.0817,
#     'sup': 11.9082},
#    {'ant': ['5.0_P', '0.0_F'],
#     'conf': 31.1594,
#     'cons': '1_D',
#     'lift': 81.6471,
#     'sup': 19.7991},
#    {'ant': ['35_BMI', '2.0_P', '20_A'],
#     'conf': 30.3797,
#     'cons': '1_D',
#     'lift': 79.6041,
#     'sup': 11.3343},
#    {'ant': ['60_B', '25_BMI', '0.0_F'],
#     'conf': 28.3784,
#     'cons': '1_D',
#     'lift': 74.3599,
#     'sup': 10.6169}]},
#  '1_D,70_A,140_G,80_B,25_BMI,0.0_F,5.0_P': {2: [{'ant': ['5.0_P', '0.0_F'],
#     'conf': 31.1594,
#     'cons': '1_D',
#     'lift': 81.6471,
#     'sup': 19.7991},
#    {'ant': ['60_B', '25_BMI', '0.0_F'],
#     'conf': 28.3784,
#     'cons': '1_D',
#     'lift': 74.3599,
#     'sup': 10.6169}]}}

# %%
correctExamples = 0
for pv,rules in setOfSamples.items():
    pvoutcome = pv.split(',')[0].split('_')[0]
    vote0=0
    vote1=0
    for _,r in rules.items():
        for rule in r:
            if rule['cons'].replace('_D','')=='0':
                vote0+=1
            if rule['cons'].replace('_D','')=='1':
                vote1+=1
        if vote0>vote1:
            if pvoutcome=='0':
                correctExamples+=1
        else:
            if pvoutcome=='1':
                correctExamples+=1

# %%
correctExamples
# Out:
# 236

# %%
len(setOfSamples)
# Out:
# 551
